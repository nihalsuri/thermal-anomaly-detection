# %% [markdown]
# <a href="https://colab.research.google.com/github/nihalsuri/thermal-anomaly-detection/blob/main/notebooks/tad_mobilenet_rpi_es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Uploading all necessary data when connected to host

# %%
! gdown --id 1x4Os51uaMXDILTGo2Y_lOC9HU1jTnzi0
! gdown --id 1uxDV-sgzDUATHc5p8gW_gBKBsEVrz34x
# Out:
# 'gdown' is not recognized as an internal or external command,
# operable program or batch file.
# 'gdown' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !unzip clutch_2.zip
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Uploading data when connected to local runtime

# %%
annotations_path = 'C:/Users/Nihal/Desktop/thesis/dataset.csv'
# annotations_path = 'C:/Users/Nihal/Desktop/new_dataset.csv'
dataset_path = 'C:/Users/Nihal/Desktop/thesis/clutch_2'

# %% [markdown]
# # Data preperation for training
#
# In this section the following is done:
#
#
#
# *   Data is processed and arranged into respective **dataframes**
# *   **Custom dataset** class is created
# *   **Transforms** are done on the various datasets
# *   **Dataloaders** are created for the purposes of iteration

# %% [markdown]
# ## Import libraries

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision.utils import make_grid
from PIL import Image
from torchvision import transforms , models
from sklearn import metrics
from tabulate import tabulate
import os
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F 
import torch.optim as optim
import io
import copy
import tqdm 
import time

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device_name = torch.cuda.get_device_name()
print(device_name)
print(device)
# Out:
# NVIDIA GeForce GTX 1660 Ti with Max-Q Design
# cuda

# %%
torch.cuda.empty_cache()

# %%
torch.cuda.memory_summary(device=None, abbreviated=False)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 0            |        cudaMalloc retries: 0         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|---------------------------------------------------------------------------|\n| Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|---------------------------------------------------------------------------|\n| Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|---------------------------------------------------------------------------|\n| Allocations           |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Active allocs         |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize allocations  |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize GPU segments |       0    |       0    |       0    |       0    |\n|===========================================================================|\n'

# %% [markdown]
# ## Split data into dataframes

# %%
df = pd.read_csv(annotations_path)
train_df = df[df['dataset'].str.contains('train')]
test_df = df[df['dataset'].str.contains('test')]
val_df = df[df['dataset'].str.contains('val')]
print(train_df.shape[0])
print(test_df.shape[0])
print(val_df.shape[0])
# Out:
# 2703
# 651
# 648

# %%
# img_paths = df["img_path"]

# %%
# for i in range(img_paths.shape[0]):
#   size  = len(img_paths.at[i])
#   new_path = img_paths.at[i][:size - 24]
#   img_paths.at[i] = new_path

# %%
# img_paths.head()

# %%
# unique_lables = img_paths.unique().tolist()

# %%
# df_freq = img_paths.value_counts()
# df_freq

# %% [markdown]
# ## Custom Class
# Returns **image** and **label** for futher training

# %%
class ClutchDataset(Dataset):

    def __init__(self, dataframe, root_dir, is_train, transform=None):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.transform = transform
        self.is_train = is_train

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(self.root_dir, self.dataframe.iloc[idx, 1])
        image1 = cv2.imread(img_name)
        image_norm = cv2.normalize(
            image1, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)
        image = Image.fromarray(image_norm)
        label = torch.tensor(int(self.dataframe.iloc[idx, 2]))
         


        if self.transform:
            image = self.transform(image)
        
        #image = transforms.functional.crop(image, 140, 360 , 240, 240) # take only right part of the system
        #image = transforms.functional.crop(image, 220, 460 , 160, 160) # take only right tip of the system 1 
        #image = transforms.functional.crop(image, 190, 510 , 140, 110) # more right 2
        #image = transforms.functional.crop(image, 190, 470 , 140, 140) # more right 3
        #image = transforms.functional.crop(image, 190, 440 , 140, 180) # more right 4
        #image = transforms.functional.crop(image, 190, 470 , 130, 150) # more right 5
        
        #image = transforms.functional.crop(image, 190, 285 , 140, 320) # mm
        image = transforms.functional.crop(image, 190, 380 , 140, 230)
        #image = transforms.functional.crop(image, 190, 430 , 140, 180) #6

        return image, label

# %% [markdown]
# ## Transforms on the datasets

# %%
# Add transforms for train, test, val dataset
input_size_h = 512
input_size_w = 640
transform_train = transforms.Compose([
   #transforms.Resize((input_size_h, input_size_w)),
    #transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    #transforms.RandomPerspective(),
    #transforms.RandomRotation((1, 8))

])

transform_valid = transforms.Compose([
    #transforms.Resize((input_size_h, input_size_w)),
    #transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor()
])

transform_test = transforms.Compose([
    #transforms.Resize((input_size_h, input_size_w)),
    #transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor()
])

# %% [markdown]
# ## Dataloaders and Iterator

# %%
def show_batch(dl):
    """Plot images grid of single batch"""
    for images, labels in dl:
        fig,ax = plt.subplots(figsize = (16,12))
        ax.set_xticks([])
        ax.set_yticks([])
        ax.imshow(make_grid(images,nrow=16).permute(1,2,0))
        break



# dataloaders
train_dataset = ClutchDataset(
    train_df, root_dir=dataset_path, is_train=True, transform=transform_train)
val_dataset = ClutchDataset(val_df, root_dir=dataset_path,
                            is_train=False, transform=transform_valid)
test_dataset = ClutchDataset(
    test_df, root_dir=dataset_path, is_train=False, transform=transform_test)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

dataloaders_dict = {}
dataloaders_dict['train'] = train_loader
dataloaders_dict['val'] = val_loader
dataloaders_dict['test'] = test_loader


# iteratre through dataloaders
train_features, train_labels = next(iter(train_loader))
print(f"Feature batch shape: {train_features.shape}")
print(f"Labels batch shape: {train_labels.shape}")
img = train_features[0].squeeze()
label = train_labels[0]

# convert image to APPEAR RGB
# rgb_train_features = np.repeat(train_features[..., np.newaxis], 3, -1)
# print(f"Feature batch shape: {rgb_train_features.shape}")
# train_features = rgb_train_features

# plt.imshow(img, cmap="gray")
# plt.axis('off')
# plt.show()
# print(f"Label: {label}")
show_batch(train_loader)
# Out:
# Feature batch shape: torch.Size([8, 3, 140, 230])
# Labels batch shape: torch.Size([8])

# %% [markdown]
# # Neural Networks
# Various different NNs tested with the same dataset

# %% [markdown]
# ### Metrics

# %%
def get_metrics(y_true, y_pred, class_mapping):

    total_predictions = [0, 0, 0]
    total_true = [0, 0, 0]

    cm = metrics.confusion_matrix(y_true, y_pred, labels=class_mapping)

    for i in range(3):
        for j in range(3):
            total_predictions[i] += cm[j][i]
            total_true[i] += cm[i][j]

    # recall and precision for each class
    r_h = cm[0][0] / total_predictions[0]
    r_m = cm[1][1] / total_predictions[1]
    r_r = cm[2][2] / total_predictions[2]
    p_h = cm[0][0] / total_true[0]
    p_m = cm[1][1] / total_true[1]
    p_r = cm[2][2] / total_true[2]

    # data for confusion matrix
    data = [["", class_mapping[0], class_mapping[1], class_mapping[2], "Total actual"],
            [class_mapping[0], cm[0][0], cm[0][1], cm[0][2], total_true[0]],
            [class_mapping[1], cm[1][0], cm[1][1], cm[1][2], total_true[1]],
            [class_mapping[2], cm[2][0], cm[2][1], cm[2][2], total_true[2]],
            ["Total predicted:", total_predictions[0], total_predictions[1], total_predictions[2], sum(total_true)]]

    # data for f1 score for each class
    data_f1 = [["Class", "F1-score"],
               ["Healthy", round((2 * p_h * r_h) / (p_h + r_h), 2)],
               ["Misalignment", round((2 * p_m * r_m) / (p_m + r_m), 2)],
               ["Rotor damage", round((2 * p_r * r_r) / (p_r + r_r), 2)]]

    # printing confusion matrix, f1 score table, recall and precision
    print(tabulate(data, tablefmt="simple_grid"))
    print()
    print(tabulate(data_f1, tablefmt="simple_grid"))
    print(f"\nRecall for healthy class: {round(r_h, 2)}")
    print(f"Recall for misalignment class: {round(r_m, 2)}")
    print(f"Recall for rotor damage class: {round(r_r, 2)}")
    print(f"\nPrecision for healthy class: {round(p_h, 2)}")
    print(f"Precision for misalignment class: {round(p_m, 2)}")
    print(f"Precision for rotor damage class: {round(p_r, 2)}")

# %% [markdown]
# ## MobileNet V2( Transfer Learning )
#
# With the resnet152 architecture instead of developing the DNN(Dense Neural Network) on our own we take a **transfer learning approach**, so the **classification** block will be modified and the input into the first **convolutional block** will be made to look-like its 3-channel as the pretrained model accepts ony 3-channel images, this is done by taking the same grayscale image and mapping it onto the three axes.

# %% [markdown]
# ### Pretrained Model

# %%
mobileNet = models.mobilenet_v2(pretrained=True)
mobileNet = mobileNet.cuda() if device else mobileNet
mobileNet
# Out:
# c:\users\nihal\appdata\local\programs\python\python37\lib\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# c:\users\nihal\appdata\local\programs\python\python37\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# ### Changes to pretrained model to fit dataset

# %%
mobileNet.classifier[1] = nn.Linear(1280, 3)
mobileNet.classifier[1] = mobileNet.classifier[1].cuda()
mobileNet
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ### Hyperparameters

# %%
path_res = "C:/Users/Nihal/Desktop/thermal-anomaly-detection/models/mobilenetv2-1.pt"
LEARNING_RATE = 0.0001

loss_val = []
train_acc = []
class_mapping = ['healthy', 'misalignment', 'rotor damage']

# %% [markdown]
# ### Training per epoch

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(mobileNet.parameters(), lr=LEARNING_RATE, momentum=0.9)
n_epochs = 32
print_every = 10
valid_loss_min = np.Inf
val_loss = []
val_acc = []
train_loss = []
train_acc = []
total_step = len(train_loader)
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
    correct = 0
    total=0
    print(f'Epoch {epoch}\n')
    for batch_idx, (data_, target_) in enumerate(train_loader):
        data_, target_ = data_.to(device), target_.to(device)
        optimizer.zero_grad()
        
        outputs = mobileNet(data_)
        loss = criterion(outputs, target_)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _,pred = torch.max(outputs, dim=1)
        correct += torch.sum(pred==target_).item()
        total += target_.size(0)
        if (batch_idx) % 10 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch, n_epochs, batch_idx, total_step, loss.item()))
    train_acc.append(100 * correct / total)
    train_loss.append(running_loss/total_step)
    print(f'\ntrain-loss: {np.mean(train_loss):.4f}, train-acc: {(100 * correct/total):.4f}')
    batch_loss = 0
    total_t=0
    correct_t=0
    with torch.no_grad():
        mobileNet.eval()
        for data_t, target_t in (test_loader):
            data_t, target_t = data_t.to(device), target_t.to(device)
            outputs_t = mobileNet(data_t)
            loss_t = criterion(outputs_t, target_t)
            batch_loss += loss_t.item()
            _,pred_t = torch.max(outputs_t, dim=1)
            correct_t += torch.sum(pred_t==target_t).item()
            total_t += target_t.size(0)
        val_acc.append(100 * correct_t/total_t)
        val_loss.append(batch_loss/len(test_loader))
        network_learned = batch_loss < valid_loss_min
        print(f'validation loss: {np.mean(val_loss):.4f}, validation acc: {(100 * correct_t/total_t):.4f}\n')

        
        if network_learned:
            valid_loss_min = batch_loss
            torch.save(mobileNet.state_dict(), path_res)
            print('Improvement-Detected, save-model')
    mobileNet.train()
# Out:
# Epoch 1
#
# Epoch [1/32], Step [0/338], Loss: 1.1769
# Epoch [1/32], Step [10/338], Loss: 0.8269
# Epoch [1/32], Step [20/338], Loss: 1.0331
# Epoch [1/32], Step [30/338], Loss: 0.5425
# Epoch [1/32], Step [40/338], Loss: 0.8916
# Epoch [1/32], Step [50/338], Loss: 0.5871
# Epoch [1/32], Step [60/338], Loss: 0.5865
# Epoch [1/32], Step [70/338], Loss: 0.4932
# Epoch [1/32], Step [80/338], Loss: 0.2548
# Epoch [1/32], Step [90/338], Loss: 0.9918
# Epoch [1/32], Step [100/338], Loss: 0.2803
# Epoch [1/32], Step [110/338], Loss: 0.2424
# Epoch [1/32], Step [120/338], Loss: 0.1985
# Epoch [1/32], Step [130/338], Loss: 0.3171
# Epoch [1/32], Step [140/338], Loss: 0.1759
# Epoch [1/32], Step [150/338], Loss: 0.4545
# Epoch [1/32], Step [160/338], Loss: 0.5963
# Epoch [1/32], Step [170/338], Loss: 0.1907
# Epoch [1/32], Step [180/338], Loss: 0.1556
# Epoch [1/32], Step [190/338], Loss: 0.1314
# Epoch [1/32], Step [200/338], Loss: 0.2063
# Epoch [1/32], Step [210/338], Loss: 0.1419
# Epoch [1/32], Step [220/338], Loss: 0.1315
# Epoch [1/32], Step [230/338], Loss: 0.1339
# Epoch [1/32], Step [240/338], Loss: 0.2679
# Epoch [1/32], Step [250/338], Loss: 0.2093
# Epoch [1/32], Step [260/338], Loss: 0.1166
# Epoch [1/32], Step [270/338], Loss: 0.4644
# Epoch [1/32], Step [280/338], Loss: 0.0343
# Epoch [1/32], Step [290/338], Loss: 0.0833
# Epoch [1/32], Step [300/338], Loss: 0.0823
# Epoch [1/32], Step [310/338], Loss: 0.0401
# Epoch [1/32], Step [320/338], Loss: 0.1048
# Epoch [1/32], Step [330/338], Loss: 0.0666
#
# train-loss: 0.3242, train-acc: 91.2320
# validation loss: 0.5677, validation acc: 68.9708
#
# Improvement-Detected, save-model
# Epoch 2
#
# Epoch [2/32], Step [0/338], Loss: 0.0397
# Epoch [2/32], Step [10/338], Loss: 0.2871
# Epoch [2/32], Step [20/338], Loss: 0.0386
# Epoch [2/32], Step [30/338], Loss: 0.0667
# Epoch [2/32], Step [40/338], Loss: 0.0559
# Epoch [2/32], Step [50/338], Loss: 0.0267
# Epoch [2/32], Step [60/338], Loss: 0.0727
# Epoch [2/32], Step [70/338], Loss: 0.1524
# Epoch [2/32], Step [80/338], Loss: 0.0360
# Epoch [2/32], Step [90/338], Loss: 0.0551
# Epoch [2/32], Step [100/338], Loss: 0.3065
# Epoch [2/32], Step [110/338], Loss: 0.0997
# Epoch [2/32], Step [120/338], Loss: 0.0388
# Epoch [2/32], Step [130/338], Loss: 0.0186
# Epoch [2/32], Step [140/338], Loss: 0.1667
# Epoch [2/32], Step [150/338], Loss: 0.0134
# Epoch [2/32], Step [160/338], Loss: 0.0412
# Epoch [2/32], Step [170/338], Loss: 0.0612
# Epoch [2/32], Step [180/338], Loss: 0.0483
# Epoch [2/32], Step [190/338], Loss: 0.1037
# Epoch [2/32], Step [200/338], Loss: 0.0816
# Epoch [2/32], Step [210/338], Loss: 0.0196
# Epoch [2/32], Step [220/338], Loss: 0.0192
# Epoch [2/32], Step [230/338], Loss: 0.0242
# Epoch [2/32], Step [240/338], Loss: 0.0169
# Epoch [2/32], Step [250/338], Loss: 0.0529
# Epoch [2/32], Step [260/338], Loss: 0.0226
# Epoch [2/32], Step [270/338], Loss: 0.0252
# Epoch [2/32], Step [280/338], Loss: 0.0116
# Epoch [2/32], Step [290/338], Loss: 0.0216
# Epoch [2/32], Step [300/338], Loss: 0.0147
# Epoch [2/32], Step [310/338], Loss: 0.0425
# Epoch [2/32], Step [320/338], Loss: 0.0866
# Epoch [2/32], Step [330/338], Loss: 0.0120
#
# train-loss: 0.1953, train-acc: 99.2601
# validation loss: 0.5703, validation acc: 70.6605
#
# Epoch 3
#
# Epoch [3/32], Step [0/338], Loss: 0.0152
# Epoch [3/32], Step [10/338], Loss: 0.0808
# Epoch [3/32], Step [20/338], Loss: 0.0383
# Epoch [3/32], Step [30/338], Loss: 0.0105
# Epoch [3/32], Step [40/338], Loss: 0.0066
# Epoch [3/32], Step [50/338], Loss: 0.0319
# Epoch [3/32], Step [60/338], Loss: 0.0158
# Epoch [3/32], Step [70/338], Loss: 0.0140
# Epoch [3/32], Step [80/338], Loss: 0.1782
# Epoch [3/32], Step [90/338], Loss: 0.0095
# Epoch [3/32], Step [100/338], Loss: 0.0152
# Epoch [3/32], Step [110/338], Loss: 0.0688
# Epoch [3/32], Step [120/338], Loss: 0.0146
# Epoch [3/32], Step [130/338], Loss: 0.0078
# Epoch [3/32], Step [140/338], Loss: 0.0053
# Epoch [3/32], Step [150/338], Loss: 0.0223
# Epoch [3/32], Step [160/338], Loss: 0.0131
# Epoch [3/32], Step [170/338], Loss: 0.0644
# Epoch [3/32], Step [180/338], Loss: 0.0329
# Epoch [3/32], Step [190/338], Loss: 0.0062
# Epoch [3/32], Step [200/338], Loss: 0.0275
# Epoch [3/32], Step [210/338], Loss: 0.0041
# Epoch [3/32], Step [220/338], Loss: 0.0983
# Epoch [3/32], Step [230/338], Loss: 0.0223
# Epoch [3/32], Step [240/338], Loss: 0.0255
# Epoch [3/32], Step [250/338], Loss: 0.0076
# Epoch [3/32], Step [260/338], Loss: 0.0086
# Epoch [3/32], Step [270/338], Loss: 0.0573
# Epoch [3/32], Step [280/338], Loss: 0.1840
# Epoch [3/32], Step [290/338], Loss: 0.0669
# Epoch [3/32], Step [300/338], Loss: 0.0801
# Epoch [3/32], Step [310/338], Loss: 0.0073
# Epoch [3/32], Step [320/338], Loss: 0.0071
# Epoch [3/32], Step [330/338], Loss: 0.0095
#
# train-loss: 0.1475, train-acc: 99.0751
# validation loss: 0.5461, validation acc: 77.4194
#
# Improvement-Detected, save-model
# Epoch 4
#
# Epoch [4/32], Step [0/338], Loss: 0.0441
# Epoch [4/32], Step [10/338], Loss: 0.0226
# Epoch [4/32], Step [20/338], Loss: 0.0031
# Epoch [4/32], Step [30/338], Loss: 0.0282
# Epoch [4/32], Step [40/338], Loss: 0.0082
# Epoch [4/32], Step [50/338], Loss: 0.0195
# Epoch [4/32], Step [60/338], Loss: 0.0389
# Epoch [4/32], Step [70/338], Loss: 0.0047
# Epoch [4/32], Step [80/338], Loss: 0.1109
# Epoch [4/32], Step [90/338], Loss: 0.1231
# Epoch [4/32], Step [100/338], Loss: 0.0088
# Epoch [4/32], Step [110/338], Loss: 0.0040
# Epoch [4/32], Step [120/338], Loss: 0.0910
# Epoch [4/32], Step [130/338], Loss: 0.0110
# Epoch [4/32], Step [140/338], Loss: 0.0024
# Epoch [4/32], Step [150/338], Loss: 0.0518
# Epoch [4/32], Step [160/338], Loss: 0.0044
# Epoch [4/32], Step [170/338], Loss: 0.0040
# Epoch [4/32], Step [180/338], Loss: 0.1045
# Epoch [4/32], Step [190/338], Loss: 0.0067
# Epoch [4/32], Step [200/338], Loss: 0.0054
# Epoch [4/32], Step [210/338], Loss: 0.0183
# Epoch [4/32], Step [220/338], Loss: 0.1700
# Epoch [4/32], Step [230/338], Loss: 0.0173
# Epoch [4/32], Step [240/338], Loss: 0.0024
# Epoch [4/32], Step [250/338], Loss: 0.0527
# Epoch [4/32], Step [260/338], Loss: 0.0374
# Epoch [4/32], Step [270/338], Loss: 0.0019
# Epoch [4/32], Step [280/338], Loss: 0.0023
# Epoch [4/32], Step [290/338], Loss: 0.0032
# Epoch [4/32], Step [300/338], Loss: 0.0054
# Epoch [4/32], Step [310/338], Loss: 0.0039
# Epoch [4/32], Step [320/338], Loss: 0.1815
# Epoch [4/32], Step [330/338], Loss: 0.0031
#
# train-loss: 0.1184, train-acc: 99.7040
# validation loss: 0.5666, validation acc: 72.5038
#
# Epoch 5
#
# Epoch [5/32], Step [0/338], Loss: 0.0029
# Epoch [5/32], Step [10/338], Loss: 0.0022
# Epoch [5/32], Step [20/338], Loss: 0.0390
# Epoch [5/32], Step [30/338], Loss: 0.0068
# Epoch [5/32], Step [40/338], Loss: 0.0028
# Epoch [5/32], Step [50/338], Loss: 0.0184
# Epoch [5/32], Step [60/338], Loss: 0.0321
# Epoch [5/32], Step [70/338], Loss: 0.4689
# Epoch [5/32], Step [80/338], Loss: 0.0106
# Epoch [5/32], Step [90/338], Loss: 0.0020
# Epoch [5/32], Step [100/338], Loss: 0.0033
# Epoch [5/32], Step [110/338], Loss: 0.0837
# Epoch [5/32], Step [120/338], Loss: 0.0012
# Epoch [5/32], Step [130/338], Loss: 0.0124
# Epoch [5/32], Step [140/338], Loss: 0.0065
# Epoch [5/32], Step [150/338], Loss: 0.0267
# Epoch [5/32], Step [160/338], Loss: 0.0099
# Epoch [5/32], Step [170/338], Loss: 0.0144
# Epoch [5/32], Step [180/338], Loss: 0.0076
# Epoch [5/32], Step [190/338], Loss: 0.0056
# Epoch [5/32], Step [200/338], Loss: 0.0086
# Epoch [5/32], Step [210/338], Loss: 0.0050
# Epoch [5/32], Step [220/338], Loss: 0.0051
# Epoch [5/32], Step [230/338], Loss: 0.0066
# Epoch [5/32], Step [240/338], Loss: 0.0132
# Epoch [5/32], Step [250/338], Loss: 0.0046
# Epoch [5/32], Step [260/338], Loss: 0.0019
# Epoch [5/32], Step [270/338], Loss: 0.0065
# Epoch [5/32], Step [280/338], Loss: 0.0043
# Epoch [5/32], Step [290/338], Loss: 0.0059
# Epoch [5/32], Step [300/338], Loss: 0.0042
# Epoch [5/32], Step [310/338], Loss: 0.0387
# Epoch [5/32], Step [320/338], Loss: 0.0044
# Epoch [5/32], Step [330/338], Loss: 0.0344
#
# train-loss: 0.0992, train-acc: 99.5930
# validation loss: 0.5309, validation acc: 80.6452
#
# Improvement-Detected, save-model
# Epoch 6
#
# Epoch [6/32], Step [0/338], Loss: 0.0041
# Epoch [6/32], Step [10/338], Loss: 0.0020
# Epoch [6/32], Step [20/338], Loss: 0.0150
# Epoch [6/32], Step [30/338], Loss: 0.0578
# Epoch [6/32], Step [40/338], Loss: 0.0013
# Epoch [6/32], Step [50/338], Loss: 0.0044
# Epoch [6/32], Step [60/338], Loss: 0.0155
# Epoch [6/32], Step [70/338], Loss: 0.0026
# Epoch [6/32], Step [80/338], Loss: 0.0170
# Epoch [6/32], Step [90/338], Loss: 0.0276
# Epoch [6/32], Step [100/338], Loss: 0.0063
# Epoch [6/32], Step [110/338], Loss: 0.0573
# Epoch [6/32], Step [120/338], Loss: 0.0047
# Epoch [6/32], Step [130/338], Loss: 0.0038
# Epoch [6/32], Step [140/338], Loss: 0.1587
# Epoch [6/32], Step [150/338], Loss: 0.0016
# Epoch [6/32], Step [160/338], Loss: 0.0043
# Epoch [6/32], Step [170/338], Loss: 0.0036
# Epoch [6/32], Step [180/338], Loss: 0.0037
# Epoch [6/32], Step [190/338], Loss: 0.0011
# Epoch [6/32], Step [200/338], Loss: 0.0212
# Epoch [6/32], Step [210/338], Loss: 0.0012
# Epoch [6/32], Step [220/338], Loss: 0.0146
# Epoch [6/32], Step [230/338], Loss: 0.0023
# Epoch [6/32], Step [240/338], Loss: 0.0008
# Epoch [6/32], Step [250/338], Loss: 0.0018
# Epoch [6/32], Step [260/338], Loss: 0.0010
# Epoch [6/32], Step [270/338], Loss: 0.0100
# Epoch [6/32], Step [280/338], Loss: 0.0022
# Epoch [6/32], Step [290/338], Loss: 0.0035
# Epoch [6/32], Step [300/338], Loss: 0.0016
# Epoch [6/32], Step [310/338], Loss: 0.0040
# Epoch [6/32], Step [320/338], Loss: 0.0009
# Epoch [6/32], Step [330/338], Loss: 0.0191
#
# train-loss: 0.0862, train-acc: 99.6670
# validation loss: 0.5332, validation acc: 77.2657
#
# Epoch 7
#
# Epoch [7/32], Step [0/338], Loss: 0.2428
# Epoch [7/32], Step [10/338], Loss: 0.0100
# Epoch [7/32], Step [20/338], Loss: 0.0014
# Epoch [7/32], Step [30/338], Loss: 0.0174
# Epoch [7/32], Step [40/338], Loss: 0.0159
# Epoch [7/32], Step [50/338], Loss: 0.0023
# Epoch [7/32], Step [60/338], Loss: 0.0066
# Epoch [7/32], Step [70/338], Loss: 0.0056
# Epoch [7/32], Step [80/338], Loss: 0.0170
# Epoch [7/32], Step [90/338], Loss: 0.0054
# Epoch [7/32], Step [100/338], Loss: 0.0111
# Epoch [7/32], Step [110/338], Loss: 0.0079
# Epoch [7/32], Step [120/338], Loss: 0.0059
# Epoch [7/32], Step [130/338], Loss: 0.0008
# Epoch [7/32], Step [140/338], Loss: 0.0017
# Epoch [7/32], Step [150/338], Loss: 0.0016
# Epoch [7/32], Step [160/338], Loss: 0.0012
# Epoch [7/32], Step [170/338], Loss: 0.0023
# Epoch [7/32], Step [180/338], Loss: 0.0010
# Epoch [7/32], Step [190/338], Loss: 0.0025
# Epoch [7/32], Step [200/338], Loss: 0.0066
# Epoch [7/32], Step [210/338], Loss: 0.0037
# Epoch [7/32], Step [220/338], Loss: 0.0008
# Epoch [7/32], Step [230/338], Loss: 0.0011
# Epoch [7/32], Step [240/338], Loss: 0.0011
# Epoch [7/32], Step [250/338], Loss: 0.0328
# Epoch [7/32], Step [260/338], Loss: 0.0033
# Epoch [7/32], Step [270/338], Loss: 0.0177
# Epoch [7/32], Step [280/338], Loss: 0.0113
# Epoch [7/32], Step [290/338], Loss: 0.0015
# Epoch [7/32], Step [300/338], Loss: 0.0187
# Epoch [7/32], Step [310/338], Loss: 0.0006
# Epoch [7/32], Step [320/338], Loss: 0.0014
# Epoch [7/32], Step [330/338], Loss: 0.0045
#
# train-loss: 0.0763, train-acc: 99.8520
# validation loss: 0.5175, validation acc: 78.0338
#
# Epoch 8
#
# Epoch [8/32], Step [0/338], Loss: 0.0042
# Epoch [8/32], Step [10/338], Loss: 0.0130
# Epoch [8/32], Step [20/338], Loss: 0.0045
# Epoch [8/32], Step [30/338], Loss: 0.0010
# Epoch [8/32], Step [40/338], Loss: 0.0062
# Epoch [8/32], Step [50/338], Loss: 0.0040
# Epoch [8/32], Step [60/338], Loss: 0.0027
# Epoch [8/32], Step [70/338], Loss: 0.0012
# Epoch [8/32], Step [80/338], Loss: 0.0102
# Epoch [8/32], Step [90/338], Loss: 0.0021
# Epoch [8/32], Step [100/338], Loss: 0.0699
# Epoch [8/32], Step [110/338], Loss: 0.0051
# Epoch [8/32], Step [120/338], Loss: 0.0623
# Epoch [8/32], Step [130/338], Loss: 0.0007
# Epoch [8/32], Step [140/338], Loss: 0.0006
# Epoch [8/32], Step [150/338], Loss: 0.0007
# Epoch [8/32], Step [160/338], Loss: 0.0009
# Epoch [8/32], Step [170/338], Loss: 0.0018
# Epoch [8/32], Step [180/338], Loss: 0.0161
# Epoch [8/32], Step [190/338], Loss: 0.6557
# Epoch [8/32], Step [200/338], Loss: 0.0024
# Epoch [8/32], Step [210/338], Loss: 0.0067
# Epoch [8/32], Step [220/338], Loss: 0.0008
# Epoch [8/32], Step [230/338], Loss: 0.0021
# Epoch [8/32], Step [240/338], Loss: 0.0133
# Epoch [8/32], Step [250/338], Loss: 0.0358
# Epoch [8/32], Step [260/338], Loss: 0.0012
# Epoch [8/32], Step [270/338], Loss: 0.1052
# Epoch [8/32], Step [280/338], Loss: 0.0130
# Epoch [8/32], Step [290/338], Loss: 0.0030
# Epoch [8/32], Step [300/338], Loss: 0.0021
# Epoch [8/32], Step [310/338], Loss: 0.0521
# Epoch [8/32], Step [320/338], Loss: 0.0011
# Epoch [8/32], Step [330/338], Loss: 0.0013
#
# train-loss: 0.0692, train-acc: 99.4451
# validation loss: 0.5151, validation acc: 79.4163
#
# Epoch 9
#
# Epoch [9/32], Step [0/338], Loss: 0.0050
# Epoch [9/32], Step [10/338], Loss: 0.0014
# Epoch [9/32], Step [20/338], Loss: 0.0106
# Epoch [9/32], Step [30/338], Loss: 0.0005
# Epoch [9/32], Step [40/338], Loss: 0.0063
# Epoch [9/32], Step [50/338], Loss: 0.0927
# Epoch [9/32], Step [60/338], Loss: 0.0072
# Epoch [9/32], Step [70/338], Loss: 0.0011
# Epoch [9/32], Step [80/338], Loss: 0.0011
# Epoch [9/32], Step [90/338], Loss: 0.0347
# Epoch [9/32], Step [100/338], Loss: 0.0018
# Epoch [9/32], Step [110/338], Loss: 0.0063
# Epoch [9/32], Step [120/338], Loss: 0.0006
# Epoch [9/32], Step [130/338], Loss: 0.0104
# Epoch [9/32], Step [140/338], Loss: 0.0012
# Epoch [9/32], Step [150/338], Loss: 0.0113
# Epoch [9/32], Step [160/338], Loss: 0.0007
# Epoch [9/32], Step [170/338], Loss: 0.0016
# Epoch [9/32], Step [180/338], Loss: 0.0063
# Epoch [9/32], Step [190/338], Loss: 0.0009
# Epoch [9/32], Step [200/338], Loss: 0.0033
# Epoch [9/32], Step [210/338], Loss: 0.0016
# Epoch [9/32], Step [220/338], Loss: 0.0037
# Epoch [9/32], Step [230/338], Loss: 0.0039
# Epoch [9/32], Step [240/338], Loss: 0.0004
# Epoch [9/32], Step [250/338], Loss: 0.0034
# Epoch [9/32], Step [260/338], Loss: 0.0005
# Epoch [9/32], Step [270/338], Loss: 0.0012
# Epoch [9/32], Step [280/338], Loss: 0.0068
# Epoch [9/32], Step [290/338], Loss: 0.0005
# Epoch [9/32], Step [300/338], Loss: 0.0005
# Epoch [9/32], Step [310/338], Loss: 0.0423
# Epoch [9/32], Step [320/338], Loss: 0.0040
# Epoch [9/32], Step [330/338], Loss: 0.0015
#
# train-loss: 0.0632, train-acc: 99.8890
# validation loss: 0.5069, validation acc: 80.3379
#
# Epoch 10
#
# Epoch [10/32], Step [0/338], Loss: 0.0011
# Epoch [10/32], Step [10/338], Loss: 0.0005
# Epoch [10/32], Step [20/338], Loss: 0.0078
# Epoch [10/32], Step [30/338], Loss: 0.0009
# Epoch [10/32], Step [40/338], Loss: 0.0031
# Epoch [10/32], Step [50/338], Loss: 0.0023
# Epoch [10/32], Step [60/338], Loss: 0.0052
# Epoch [10/32], Step [70/338], Loss: 0.0006
# Epoch [10/32], Step [80/338], Loss: 0.0063
# Epoch [10/32], Step [90/338], Loss: 0.0012
# Epoch [10/32], Step [100/338], Loss: 0.0075
# Epoch [10/32], Step [110/338], Loss: 0.0022
# Epoch [10/32], Step [120/338], Loss: 0.0083
# Epoch [10/32], Step [130/338], Loss: 0.0303
# Epoch [10/32], Step [140/338], Loss: 0.0039
# Epoch [10/32], Step [150/338], Loss: 0.0005
# Epoch [10/32], Step [160/338], Loss: 0.0137
# Epoch [10/32], Step [170/338], Loss: 0.0006
# Epoch [10/32], Step [180/338], Loss: 0.0008
# Epoch [10/32], Step [190/338], Loss: 0.0006
# Epoch [10/32], Step [200/338], Loss: 0.0007
# Epoch [10/32], Step [210/338], Loss: 0.0016
# Epoch [10/32], Step [220/338], Loss: 0.0025
# Epoch [10/32], Step [230/338], Loss: 0.0013
# Epoch [10/32], Step [240/338], Loss: 0.0095
# Epoch [10/32], Step [250/338], Loss: 0.0410
# Epoch [10/32], Step [260/338], Loss: 0.0015
# Epoch [10/32], Step [270/338], Loss: 0.0008
# Epoch [10/32], Step [280/338], Loss: 0.0003
# Epoch [10/32], Step [290/338], Loss: 0.0025
# Epoch [10/32], Step [300/338], Loss: 0.0070
# Epoch [10/32], Step [310/338], Loss: 0.0108
# Epoch [10/32], Step [320/338], Loss: 0.0012
# Epoch [10/32], Step [330/338], Loss: 0.0005
#
# train-loss: 0.0590, train-acc: 99.4081
# validation loss: 0.5111, validation acc: 76.9585
#
# Epoch 11
#
# Epoch [11/32], Step [0/338], Loss: 0.0004
# Epoch [11/32], Step [10/338], Loss: 0.0002
# Epoch [11/32], Step [20/338], Loss: 0.0022
# Epoch [11/32], Step [30/338], Loss: 0.0009
# Epoch [11/32], Step [40/338], Loss: 0.0084
# Epoch [11/32], Step [50/338], Loss: 0.0015
# Epoch [11/32], Step [60/338], Loss: 0.0005
# Epoch [11/32], Step [70/338], Loss: 0.0016
# Epoch [11/32], Step [80/338], Loss: 0.0015
# Epoch [11/32], Step [90/338], Loss: 0.0039
# Epoch [11/32], Step [100/338], Loss: 0.0023
# Epoch [11/32], Step [110/338], Loss: 0.0006
# Epoch [11/32], Step [120/338], Loss: 0.0012
# Epoch [11/32], Step [130/338], Loss: 0.0007
# Epoch [11/32], Step [140/338], Loss: 0.3693
# Epoch [11/32], Step [150/338], Loss: 0.0068
# Epoch [11/32], Step [160/338], Loss: 0.0012
# Epoch [11/32], Step [170/338], Loss: 0.0101
# Epoch [11/32], Step [180/338], Loss: 0.0010
# Epoch [11/32], Step [190/338], Loss: 0.0161
# Epoch [11/32], Step [200/338], Loss: 0.0118
# Epoch [11/32], Step [210/338], Loss: 0.0039
# Epoch [11/32], Step [220/338], Loss: 0.0110
# Epoch [11/32], Step [230/338], Loss: 0.0004
# Epoch [11/32], Step [240/338], Loss: 0.0003
# Epoch [11/32], Step [250/338], Loss: 0.0012
# Epoch [11/32], Step [260/338], Loss: 0.0057
# Epoch [11/32], Step [270/338], Loss: 0.0013
# Epoch [11/32], Step [280/338], Loss: 0.0003
# Epoch [11/32], Step [290/338], Loss: 0.0010
# Epoch [11/32], Step [300/338], Loss: 0.0005
# Epoch [11/32], Step [310/338], Loss: 0.0005
# Epoch [11/32], Step [320/338], Loss: 0.0005
# Epoch [11/32], Step [330/338], Loss: 0.0008
#
# train-loss: 0.0550, train-acc: 99.8150
# validation loss: 0.5122, validation acc: 77.8802
#
# Epoch 12
#
# Epoch [12/32], Step [0/338], Loss: 0.0012
# Epoch [12/32], Step [10/338], Loss: 0.0281
# Epoch [12/32], Step [20/338], Loss: 0.0028
# Epoch [12/32], Step [30/338], Loss: 0.0011
# Epoch [12/32], Step [40/338], Loss: 0.0132
# Epoch [12/32], Step [50/338], Loss: 0.0009
# Epoch [12/32], Step [60/338], Loss: 0.0497
# Epoch [12/32], Step [70/338], Loss: 0.0004
# Epoch [12/32], Step [80/338], Loss: 0.0025
# Epoch [12/32], Step [90/338], Loss: 0.0014
# Epoch [12/32], Step [100/338], Loss: 0.0028
# Epoch [12/32], Step [110/338], Loss: 0.0119
# Epoch [12/32], Step [120/338], Loss: 0.0004
# Epoch [12/32], Step [130/338], Loss: 0.0088
# Epoch [12/32], Step [140/338], Loss: 0.0006
# Epoch [12/32], Step [150/338], Loss: 0.0022
# Epoch [12/32], Step [160/338], Loss: 0.4652
# Epoch [12/32], Step [170/338], Loss: 0.0005
# Epoch [12/32], Step [180/338], Loss: 0.0039
# Epoch [12/32], Step [190/338], Loss: 0.0348
# Epoch [12/32], Step [200/338], Loss: 0.0019
# Epoch [12/32], Step [210/338], Loss: 0.0009
# Epoch [12/32], Step [220/338], Loss: 0.0075
# Epoch [12/32], Step [230/338], Loss: 0.3590
# Epoch [12/32], Step [240/338], Loss: 0.0036
# Epoch [12/32], Step [250/338], Loss: 0.0005
# Epoch [12/32], Step [260/338], Loss: 0.0058
# Epoch [12/32], Step [270/338], Loss: 0.0012
# Epoch [12/32], Step [280/338], Loss: 0.1284
# Epoch [12/32], Step [290/338], Loss: 0.0004
# Epoch [12/32], Step [300/338], Loss: 0.0003
# Epoch [12/32], Step [310/338], Loss: 0.0010
# Epoch [12/32], Step [320/338], Loss: 0.0146
# Epoch [12/32], Step [330/338], Loss: 0.0010
#
# train-loss: 0.0516, train-acc: 99.6670
# validation loss: 0.5057, validation acc: 78.3410
#
# Epoch 13
#
# Epoch [13/32], Step [0/338], Loss: 0.0028
# Epoch [13/32], Step [10/338], Loss: 0.0005
# Epoch [13/32], Step [20/338], Loss: 0.0004
# Epoch [13/32], Step [30/338], Loss: 0.0004
# Epoch [13/32], Step [40/338], Loss: 0.0001
# Epoch [13/32], Step [50/338], Loss: 0.0020
# Epoch [13/32], Step [60/338], Loss: 0.0709
# Epoch [13/32], Step [70/338], Loss: 0.0004
# Epoch [13/32], Step [80/338], Loss: 0.0033
# Epoch [13/32], Step [90/338], Loss: 0.0038
# Epoch [13/32], Step [100/338], Loss: 0.0021
# Epoch [13/32], Step [110/338], Loss: 0.0048
# Epoch [13/32], Step [120/338], Loss: 0.0123
# Epoch [13/32], Step [130/338], Loss: 0.0077
# Epoch [13/32], Step [140/338], Loss: 0.0007
# Epoch [13/32], Step [150/338], Loss: 0.0003
# Epoch [13/32], Step [160/338], Loss: 0.0018
# Epoch [13/32], Step [170/338], Loss: 0.0017
# Epoch [13/32], Step [180/338], Loss: 0.0091
# Epoch [13/32], Step [190/338], Loss: 0.0051
# Epoch [13/32], Step [200/338], Loss: 0.0078
# Epoch [13/32], Step [210/338], Loss: 0.0039
# Epoch [13/32], Step [220/338], Loss: 0.0008
# Epoch [13/32], Step [230/338], Loss: 0.0019
# Epoch [13/32], Step [240/338], Loss: 0.0083
# Epoch [13/32], Step [250/338], Loss: 0.0005
# Epoch [13/32], Step [260/338], Loss: 0.0073
# Epoch [13/32], Step [270/338], Loss: 0.0050
# Epoch [13/32], Step [280/338], Loss: 0.0004
# Epoch [13/32], Step [290/338], Loss: 0.0116
# Epoch [13/32], Step [300/338], Loss: 0.0026
# Epoch [13/32], Step [310/338], Loss: 0.0038
# Epoch [13/32], Step [320/338], Loss: 0.0012
# Epoch [13/32], Step [330/338], Loss: 0.0105
#
# train-loss: 0.0483, train-acc: 99.9630
# validation loss: 0.5136, validation acc: 76.4977
#
# Epoch 14
#
# Epoch [14/32], Step [0/338], Loss: 0.0003
# Epoch [14/32], Step [10/338], Loss: 0.0003
# Epoch [14/32], Step [20/338], Loss: 0.0006
# Epoch [14/32], Step [30/338], Loss: 0.0062
# Epoch [14/32], Step [40/338], Loss: 0.0040
# Epoch [14/32], Step [50/338], Loss: 0.0023
# Epoch [14/32], Step [60/338], Loss: 0.0042
# Epoch [14/32], Step [70/338], Loss: 0.0009
# Epoch [14/32], Step [80/338], Loss: 0.0023
# Epoch [14/32], Step [90/338], Loss: 0.0036
# Epoch [14/32], Step [100/338], Loss: 0.0002
# Epoch [14/32], Step [110/338], Loss: 0.0039
# Epoch [14/32], Step [120/338], Loss: 0.0064
# Epoch [14/32], Step [130/338], Loss: 0.0002
# Epoch [14/32], Step [140/338], Loss: 0.0003
# Epoch [14/32], Step [150/338], Loss: 0.0013
# Epoch [14/32], Step [160/338], Loss: 0.0013
# Epoch [14/32], Step [170/338], Loss: 0.0003
# Epoch [14/32], Step [180/338], Loss: 0.0048
# Epoch [14/32], Step [190/338], Loss: 0.0085
# Epoch [14/32], Step [200/338], Loss: 0.0024
# Epoch [14/32], Step [210/338], Loss: 0.0004
# Epoch [14/32], Step [220/338], Loss: 0.0012
# Epoch [14/32], Step [230/338], Loss: 0.0008
# Epoch [14/32], Step [240/338], Loss: 0.0002
# Epoch [14/32], Step [250/338], Loss: 0.0099
# Epoch [14/32], Step [260/338], Loss: 0.0013
# Epoch [14/32], Step [270/338], Loss: 0.0154
# Epoch [14/32], Step [280/338], Loss: 0.0032
# Epoch [14/32], Step [290/338], Loss: 0.0003
# Epoch [14/32], Step [300/338], Loss: 0.0015
# Epoch [14/32], Step [310/338], Loss: 0.0090
# Epoch [14/32], Step [320/338], Loss: 0.0047
# Epoch [14/32], Step [330/338], Loss: 0.8199
#
# train-loss: 0.0456, train-acc: 99.8150
# validation loss: 0.5175, validation acc: 78.3410
#
# Epoch 15
#
# Epoch [15/32], Step [0/338], Loss: 0.0019
# Epoch [15/32], Step [10/338], Loss: 0.0003
# Epoch [15/32], Step [20/338], Loss: 0.0040
# Epoch [15/32], Step [30/338], Loss: 0.0009
# Epoch [15/32], Step [40/338], Loss: 0.0006
# Epoch [15/32], Step [50/338], Loss: 0.0066
# Epoch [15/32], Step [60/338], Loss: 0.0012
# Epoch [15/32], Step [70/338], Loss: 0.0120
# Epoch [15/32], Step [80/338], Loss: 0.0007
# Epoch [15/32], Step [90/338], Loss: 0.0001
# Epoch [15/32], Step [100/338], Loss: 0.0011
# Epoch [15/32], Step [110/338], Loss: 0.0042
# Epoch [15/32], Step [120/338], Loss: 0.0005
# Epoch [15/32], Step [130/338], Loss: 0.0622
# Epoch [15/32], Step [140/338], Loss: 0.0003
# Epoch [15/32], Step [150/338], Loss: 0.0002
# Epoch [15/32], Step [160/338], Loss: 0.0017
# Epoch [15/32], Step [170/338], Loss: 0.0003
# Epoch [15/32], Step [180/338], Loss: 0.0003
# Epoch [15/32], Step [190/338], Loss: 0.0353
# Epoch [15/32], Step [200/338], Loss: 0.0022
# Epoch [15/32], Step [210/338], Loss: 0.0153
# Epoch [15/32], Step [220/338], Loss: 0.0003
# Epoch [15/32], Step [230/338], Loss: 0.0060
# Epoch [15/32], Step [240/338], Loss: 0.0073
# Epoch [15/32], Step [250/338], Loss: 0.0016
# Epoch [15/32], Step [260/338], Loss: 0.0003
# Epoch [15/32], Step [270/338], Loss: 0.0045
# Epoch [15/32], Step [280/338], Loss: 0.0089
# Epoch [15/32], Step [290/338], Loss: 0.0019
# Epoch [15/32], Step [300/338], Loss: 0.0004
# Epoch [15/32], Step [310/338], Loss: 0.0012
# Epoch [15/32], Step [320/338], Loss: 0.0037
# Epoch [15/32], Step [330/338], Loss: 0.0008
#
# train-loss: 0.0430, train-acc: 99.9630
# validation loss: 0.5157, validation acc: 80.7988
#
# Epoch 16
#
# Epoch [16/32], Step [0/338], Loss: 0.0036
# Epoch [16/32], Step [10/338], Loss: 0.0002
# Epoch [16/32], Step [20/338], Loss: 0.0874
# Epoch [16/32], Step [30/338], Loss: 0.0002
# Epoch [16/32], Step [40/338], Loss: 0.0007
# Epoch [16/32], Step [50/338], Loss: 0.0031
# Epoch [16/32], Step [60/338], Loss: 0.0002
# Epoch [16/32], Step [70/338], Loss: 0.0035
# Epoch [16/32], Step [80/338], Loss: 0.0004
# Epoch [16/32], Step [90/338], Loss: 0.1541
# Epoch [16/32], Step [100/338], Loss: 0.0040
# Epoch [16/32], Step [110/338], Loss: 0.0090
# Epoch [16/32], Step [120/338], Loss: 0.4471
# Epoch [16/32], Step [130/338], Loss: 0.0006
# Epoch [16/32], Step [140/338], Loss: 0.0017
# Epoch [16/32], Step [150/338], Loss: 0.0049
# Epoch [16/32], Step [160/338], Loss: 0.0102
# Epoch [16/32], Step [170/338], Loss: 0.0002
# Epoch [16/32], Step [180/338], Loss: 0.0003
# Epoch [16/32], Step [190/338], Loss: 0.0169
# Epoch [16/32], Step [200/338], Loss: 0.0004
# Epoch [16/32], Step [210/338], Loss: 0.0006
# Epoch [16/32], Step [220/338], Loss: 0.0648
# Epoch [16/32], Step [230/338], Loss: 0.0028
# Epoch [16/32], Step [240/338], Loss: 0.0002
# Epoch [16/32], Step [250/338], Loss: 0.0001
# Epoch [16/32], Step [260/338], Loss: 0.0287
# Epoch [16/32], Step [270/338], Loss: 0.0001
# Epoch [16/32], Step [280/338], Loss: 0.0070
# Epoch [16/32], Step [290/338], Loss: 0.0022
# Epoch [16/32], Step [300/338], Loss: 0.0001
# Epoch [16/32], Step [310/338], Loss: 0.0004
# Epoch [16/32], Step [320/338], Loss: 0.0018
# Epoch [16/32], Step [330/338], Loss: 0.0003
#
# train-loss: 0.0408, train-acc: 99.8890
# validation loss: 0.5097, validation acc: 80.1843
#
# Epoch 17
#
# Epoch [17/32], Step [0/338], Loss: 0.0001
# Epoch [17/32], Step [10/338], Loss: 0.0002
# Epoch [17/32], Step [20/338], Loss: 0.0007
# Epoch [17/32], Step [30/338], Loss: 0.0230
# Epoch [17/32], Step [40/338], Loss: 0.0007
# Epoch [17/32], Step [50/338], Loss: 0.0009
# Epoch [17/32], Step [60/338], Loss: 0.0003
# Epoch [17/32], Step [70/338], Loss: 0.0097
# Epoch [17/32], Step [80/338], Loss: 0.3204
# Epoch [17/32], Step [90/338], Loss: 0.0003
# Epoch [17/32], Step [100/338], Loss: 0.0201
# Epoch [17/32], Step [110/338], Loss: 0.0002
# Epoch [17/32], Step [120/338], Loss: 0.0018
# Epoch [17/32], Step [130/338], Loss: 0.0020
# Epoch [17/32], Step [140/338], Loss: 0.0007
# Epoch [17/32], Step [150/338], Loss: 0.0096
# Epoch [17/32], Step [160/338], Loss: 0.0009
# Epoch [17/32], Step [170/338], Loss: 0.0036
# Epoch [17/32], Step [180/338], Loss: 0.0002
# Epoch [17/32], Step [190/338], Loss: 0.0005
# Epoch [17/32], Step [200/338], Loss: 0.0008
# Epoch [17/32], Step [210/338], Loss: 0.0001
# Epoch [17/32], Step [220/338], Loss: 0.0004
# Epoch [17/32], Step [230/338], Loss: 0.0022
# Epoch [17/32], Step [240/338], Loss: 0.0002
# Epoch [17/32], Step [250/338], Loss: 0.0027
# Epoch [17/32], Step [260/338], Loss: 0.0004
# Epoch [17/32], Step [270/338], Loss: 0.0013
# Epoch [17/32], Step [280/338], Loss: 0.0003
# Epoch [17/32], Step [290/338], Loss: 0.0002
# Epoch [17/32], Step [300/338], Loss: 0.0006
# Epoch [17/32], Step [310/338], Loss: 0.0001
# Epoch [17/32], Step [320/338], Loss: 0.0023
# Epoch [17/32], Step [330/338], Loss: 0.0031
#
# train-loss: 0.0389, train-acc: 99.7780
# validation loss: 0.5102, validation acc: 79.2627
#
# Epoch 18
#
# Epoch [18/32], Step [0/338], Loss: 0.0001
# Epoch [18/32], Step [10/338], Loss: 0.0064
# Epoch [18/32], Step [20/338], Loss: 0.0080
# Epoch [18/32], Step [30/338], Loss: 0.0038
# Epoch [18/32], Step [40/338], Loss: 0.0090
# Epoch [18/32], Step [50/338], Loss: 0.0002
# Epoch [18/32], Step [60/338], Loss: 0.0004
# Epoch [18/32], Step [70/338], Loss: 0.0039
# Epoch [18/32], Step [80/338], Loss: 0.0024
# Epoch [18/32], Step [90/338], Loss: 0.0008
# Epoch [18/32], Step [100/338], Loss: 0.0013
# Epoch [18/32], Step [110/338], Loss: 0.0034
# Epoch [18/32], Step [120/338], Loss: 0.0006
# Epoch [18/32], Step [130/338], Loss: 0.0037
# Epoch [18/32], Step [140/338], Loss: 0.0001
# Epoch [18/32], Step [150/338], Loss: 0.0002
# Epoch [18/32], Step [160/338], Loss: 0.0010
# Epoch [18/32], Step [170/338], Loss: 0.0077
# Epoch [18/32], Step [180/338], Loss: 0.0001
# Epoch [18/32], Step [190/338], Loss: 0.0001
# Epoch [18/32], Step [200/338], Loss: 0.0005
# Epoch [18/32], Step [210/338], Loss: 0.0038
# Epoch [18/32], Step [220/338], Loss: 0.0022
# Epoch [18/32], Step [230/338], Loss: 0.0067
# Epoch [18/32], Step [240/338], Loss: 0.0011
# Epoch [18/32], Step [250/338], Loss: 0.0055
# Epoch [18/32], Step [260/338], Loss: 0.0001
# Epoch [18/32], Step [270/338], Loss: 0.0007
# Epoch [18/32], Step [280/338], Loss: 0.0012
# Epoch [18/32], Step [290/338], Loss: 0.0003
# Epoch [18/32], Step [300/338], Loss: 0.0045
# Epoch [18/32], Step [310/338], Loss: 0.0004
# Epoch [18/32], Step [320/338], Loss: 0.0037
# Epoch [18/32], Step [330/338], Loss: 0.0006
#
# train-loss: 0.0372, train-acc: 99.9630
# validation loss: 0.5090, validation acc: 78.0338
#
# Epoch 19
#
# Epoch [19/32], Step [0/338], Loss: 0.0080
# Epoch [19/32], Step [10/338], Loss: 0.0008
# Epoch [19/32], Step [20/338], Loss: 0.0009
# Epoch [19/32], Step [30/338], Loss: 0.0005
# Epoch [19/32], Step [40/338], Loss: 0.0025
# Epoch [19/32], Step [50/338], Loss: 0.0005
# Epoch [19/32], Step [60/338], Loss: 0.0060
# Epoch [19/32], Step [70/338], Loss: 0.0008
# Epoch [19/32], Step [80/338], Loss: 0.0010
# Epoch [19/32], Step [90/338], Loss: 0.0981
# Epoch [19/32], Step [100/338], Loss: 0.0012
# Epoch [19/32], Step [110/338], Loss: 0.0002
# Epoch [19/32], Step [120/338], Loss: 0.0034
# Epoch [19/32], Step [130/338], Loss: 0.0024
# Epoch [19/32], Step [140/338], Loss: 0.0142
# Epoch [19/32], Step [150/338], Loss: 0.0028
# Epoch [19/32], Step [160/338], Loss: 0.0013
# Epoch [19/32], Step [170/338], Loss: 0.0001
# Epoch [19/32], Step [180/338], Loss: 0.0015
# Epoch [19/32], Step [190/338], Loss: 0.0002
# Epoch [19/32], Step [200/338], Loss: 0.0001
# Epoch [19/32], Step [210/338], Loss: 0.0001
# Epoch [19/32], Step [220/338], Loss: 0.0057
# Epoch [19/32], Step [230/338], Loss: 0.0005
# Epoch [19/32], Step [240/338], Loss: 0.0006
# Epoch [19/32], Step [250/338], Loss: 0.0175
# Epoch [19/32], Step [260/338], Loss: 0.0007
# Epoch [19/32], Step [270/338], Loss: 0.0011
# Epoch [19/32], Step [280/338], Loss: 0.0007
# Epoch [19/32], Step [290/338], Loss: 0.0005
# Epoch [19/32], Step [300/338], Loss: 0.0001
# Epoch [19/32], Step [310/338], Loss: 0.0009
# Epoch [19/32], Step [320/338], Loss: 0.0001
# Epoch [19/32], Step [330/338], Loss: 0.0002
#
# train-loss: 0.0355, train-acc: 100.0000
# validation loss: 0.5179, validation acc: 75.4224
#
# Epoch 20
#
# Epoch [20/32], Step [0/338], Loss: 0.0067
# Epoch [20/32], Step [10/338], Loss: 0.0019
# Epoch [20/32], Step [20/338], Loss: 0.0023
# Epoch [20/32], Step [30/338], Loss: 0.0006
# Epoch [20/32], Step [40/338], Loss: 0.0041
# Epoch [20/32], Step [50/338], Loss: 0.0059
# Epoch [20/32], Step [60/338], Loss: 0.0002
# Epoch [20/32], Step [70/338], Loss: 0.0004
# Epoch [20/32], Step [80/338], Loss: 0.0002
# Epoch [20/32], Step [90/338], Loss: 0.0005
# Epoch [20/32], Step [100/338], Loss: 0.0001
# Epoch [20/32], Step [110/338], Loss: 0.0001
# Epoch [20/32], Step [120/338], Loss: 0.0002
# Epoch [20/32], Step [130/338], Loss: 0.0128
# Epoch [20/32], Step [140/338], Loss: 0.0001
# Epoch [20/32], Step [150/338], Loss: 0.0002
# Epoch [20/32], Step [160/338], Loss: 0.0001
# Epoch [20/32], Step [170/338], Loss: 0.0007
# Epoch [20/32], Step [180/338], Loss: 0.0014
# Epoch [20/32], Step [190/338], Loss: 0.0021
# Epoch [20/32], Step [200/338], Loss: 0.0005
# Epoch [20/32], Step [210/338], Loss: 0.0003
# Epoch [20/32], Step [220/338], Loss: 0.0001
# Epoch [20/32], Step [230/338], Loss: 0.0002
# Epoch [20/32], Step [240/338], Loss: 0.0071
# Epoch [20/32], Step [250/338], Loss: 0.0025
# Epoch [20/32], Step [260/338], Loss: 0.0054
# Epoch [20/32], Step [270/338], Loss: 0.0008
# Epoch [20/32], Step [280/338], Loss: 0.0020
# Epoch [20/32], Step [290/338], Loss: 0.0001
# Epoch [20/32], Step [300/338], Loss: 0.0017
# Epoch [20/32], Step [310/338], Loss: 0.0001
# Epoch [20/32], Step [320/338], Loss: 0.0009
# Epoch [20/32], Step [330/338], Loss: 0.0024
#
# train-loss: 0.0340, train-acc: 99.9630
# validation loss: 0.5266, validation acc: 76.6513
#
# Epoch 21
#
# Epoch [21/32], Step [0/338], Loss: 0.0022
# Epoch [21/32], Step [10/338], Loss: 0.0004
# Epoch [21/32], Step [20/338], Loss: 0.0001
# Epoch [21/32], Step [30/338], Loss: 0.0004
# Epoch [21/32], Step [40/338], Loss: 0.0001
# Epoch [21/32], Step [50/338], Loss: 0.0352
# Epoch [21/32], Step [60/338], Loss: 0.0001
# Epoch [21/32], Step [70/338], Loss: 0.0004
# Epoch [21/32], Step [80/338], Loss: 0.0004
# Epoch [21/32], Step [90/338], Loss: 0.0012
# Epoch [21/32], Step [100/338], Loss: 0.0004
# Epoch [21/32], Step [110/338], Loss: 0.0029
# Epoch [21/32], Step [120/338], Loss: 0.0001
# Epoch [21/32], Step [130/338], Loss: 0.0042
# Epoch [21/32], Step [140/338], Loss: 0.0010
# Epoch [21/32], Step [150/338], Loss: 0.0009
# Epoch [21/32], Step [160/338], Loss: 0.0028
# Epoch [21/32], Step [170/338], Loss: 0.0005
# Epoch [21/32], Step [180/338], Loss: 0.0001
# Epoch [21/32], Step [190/338], Loss: 0.0011
# Epoch [21/32], Step [200/338], Loss: 0.0016
# Epoch [21/32], Step [210/338], Loss: 0.0004
# Epoch [21/32], Step [220/338], Loss: 0.0439
# Epoch [21/32], Step [230/338], Loss: 0.0005
# Epoch [21/32], Step [240/338], Loss: 0.0005
# Epoch [21/32], Step [250/338], Loss: 0.0021
# Epoch [21/32], Step [260/338], Loss: 0.0007
# Epoch [21/32], Step [270/338], Loss: 0.0001
# Epoch [21/32], Step [280/338], Loss: 0.0028
# Epoch [21/32], Step [290/338], Loss: 0.0010
# Epoch [21/32], Step [300/338], Loss: 0.0235
# Epoch [21/32], Step [310/338], Loss: 0.0027
# Epoch [21/32], Step [320/338], Loss: 0.0001
# Epoch [21/32], Step [330/338], Loss: 0.0211
#
# train-loss: 0.0327, train-acc: 99.8890
# validation loss: 0.5161, validation acc: 84.9462
#
# Improvement-Detected, save-model
# Epoch 22
#
# Epoch [22/32], Step [0/338], Loss: 0.0001
# Epoch [22/32], Step [10/338], Loss: 0.0001
# Epoch [22/32], Step [20/338], Loss: 0.0276
# Epoch [22/32], Step [30/338], Loss: 0.0004
# Epoch [22/32], Step [40/338], Loss: 0.0020
# Epoch [22/32], Step [50/338], Loss: 0.0651
# Epoch [22/32], Step [60/338], Loss: 0.0012
# Epoch [22/32], Step [70/338], Loss: 0.0002
# Epoch [22/32], Step [80/338], Loss: 0.0023
# Epoch [22/32], Step [90/338], Loss: 0.0022
# Epoch [22/32], Step [100/338], Loss: 0.0031
# Epoch [22/32], Step [110/338], Loss: 0.0003
# Epoch [22/32], Step [120/338], Loss: 0.0016
# Epoch [22/32], Step [130/338], Loss: 0.0013
# Epoch [22/32], Step [140/338], Loss: 0.0022
# Epoch [22/32], Step [150/338], Loss: 0.0001
# Epoch [22/32], Step [160/338], Loss: 0.0003
# Epoch [22/32], Step [170/338], Loss: 0.0001
# Epoch [22/32], Step [180/338], Loss: 0.0001
# Epoch [22/32], Step [190/338], Loss: 0.0001
# Epoch [22/32], Step [200/338], Loss: 0.0060
# Epoch [22/32], Step [210/338], Loss: 0.0001
# Epoch [22/32], Step [220/338], Loss: 0.0013
# Epoch [22/32], Step [230/338], Loss: 0.1065
# Epoch [22/32], Step [240/338], Loss: 0.0005
# Epoch [22/32], Step [250/338], Loss: 0.0001
# Epoch [22/32], Step [260/338], Loss: 0.0126
# Epoch [22/32], Step [270/338], Loss: 0.0004
# Epoch [22/32], Step [280/338], Loss: 0.0004
# Epoch [22/32], Step [290/338], Loss: 0.0020
# Epoch [22/32], Step [300/338], Loss: 0.0001
# Epoch [22/32], Step [310/338], Loss: 0.0003
# Epoch [22/32], Step [320/338], Loss: 0.0009
# Epoch [22/32], Step [330/338], Loss: 0.0013
#
# train-loss: 0.0315, train-acc: 99.9630
# validation loss: 0.5143, validation acc: 78.1874
#
# Epoch 23
#
# Epoch [23/32], Step [0/338], Loss: 0.0028
# Epoch [23/32], Step [10/338], Loss: 0.0006
# Epoch [23/32], Step [20/338], Loss: 0.0003
# Epoch [23/32], Step [30/338], Loss: 0.0081
# Epoch [23/32], Step [40/338], Loss: 0.0001
# Epoch [23/32], Step [50/338], Loss: 0.0003
# Epoch [23/32], Step [60/338], Loss: 0.0007
# Epoch [23/32], Step [70/338], Loss: 0.0013
# Epoch [23/32], Step [80/338], Loss: 0.0006
# Epoch [23/32], Step [90/338], Loss: 0.0001
# Epoch [23/32], Step [100/338], Loss: 0.0002
# Epoch [23/32], Step [110/338], Loss: 0.0043
# Epoch [23/32], Step [120/338], Loss: 0.0240
# Epoch [23/32], Step [130/338], Loss: 0.0004
# Epoch [23/32], Step [140/338], Loss: 0.0007
# Epoch [23/32], Step [150/338], Loss: 0.0046
# Epoch [23/32], Step [160/338], Loss: 0.0050
# Epoch [23/32], Step [170/338], Loss: 0.0001
# Epoch [23/32], Step [180/338], Loss: 0.0001
# Epoch [23/32], Step [190/338], Loss: 0.0005
# Epoch [23/32], Step [200/338], Loss: 0.0005
# Epoch [23/32], Step [210/338], Loss: 0.0003
# Epoch [23/32], Step [220/338], Loss: 0.0035
# Epoch [23/32], Step [230/338], Loss: 0.0033
# Epoch [23/32], Step [240/338], Loss: 0.0007
# Epoch [23/32], Step [250/338], Loss: 0.0042
# Epoch [23/32], Step [260/338], Loss: 0.0001
# Epoch [23/32], Step [270/338], Loss: 0.0001
# Epoch [23/32], Step [280/338], Loss: 0.0011
# Epoch [23/32], Step [290/338], Loss: 0.0004
# Epoch [23/32], Step [300/338], Loss: 0.0030
# Epoch [23/32], Step [310/338], Loss: 0.0009
# Epoch [23/32], Step [320/338], Loss: 0.0039
# Epoch [23/32], Step [330/338], Loss: 0.1066
#
# train-loss: 0.0304, train-acc: 99.9630
# validation loss: 0.5063, validation acc: 81.5668
#
# Epoch 24
#
# Epoch [24/32], Step [0/338], Loss: 0.0001
# Epoch [24/32], Step [10/338], Loss: 0.0011
# Epoch [24/32], Step [20/338], Loss: 0.0004
# Epoch [24/32], Step [30/338], Loss: 0.0001
# Epoch [24/32], Step [40/338], Loss: 0.0001
# Epoch [24/32], Step [50/338], Loss: 0.0458
# Epoch [24/32], Step [60/338], Loss: 0.0020
# Epoch [24/32], Step [70/338], Loss: 0.0031
# Epoch [24/32], Step [80/338], Loss: 0.0001
# Epoch [24/32], Step [90/338], Loss: 0.0612
# Epoch [24/32], Step [100/338], Loss: 0.0016
# Epoch [24/32], Step [110/338], Loss: 0.0004
# Epoch [24/32], Step [120/338], Loss: 0.0003
# Epoch [24/32], Step [130/338], Loss: 0.0031
# Epoch [24/32], Step [140/338], Loss: 0.0033
# Epoch [24/32], Step [150/338], Loss: 0.0003
# Epoch [24/32], Step [160/338], Loss: 0.0017
# Epoch [24/32], Step [170/338], Loss: 0.0002
# Epoch [24/32], Step [180/338], Loss: 0.0004
# Epoch [24/32], Step [190/338], Loss: 0.0005
# Epoch [24/32], Step [200/338], Loss: 0.0018
# Epoch [24/32], Step [210/338], Loss: 0.0011
# Epoch [24/32], Step [220/338], Loss: 0.0022
# Epoch [24/32], Step [230/338], Loss: 0.0003
# Epoch [24/32], Step [240/338], Loss: 0.0003
# Epoch [24/32], Step [250/338], Loss: 0.0006
# Epoch [24/32], Step [260/338], Loss: 0.0003
# Epoch [24/32], Step [270/338], Loss: 0.0013
# Epoch [24/32], Step [280/338], Loss: 0.0002
# Epoch [24/32], Step [290/338], Loss: 0.0043
# Epoch [24/32], Step [300/338], Loss: 0.0577
# Epoch [24/32], Step [310/338], Loss: 0.0020
# Epoch [24/32], Step [320/338], Loss: 0.0007
# Epoch [24/32], Step [330/338], Loss: 0.0071
#
# train-loss: 0.0294, train-acc: 99.9630
# validation loss: 0.5028, validation acc: 79.2627
#
# Epoch 25
#
# Epoch [25/32], Step [0/338], Loss: 0.0027
# Epoch [25/32], Step [10/338], Loss: 0.0470
# Epoch [25/32], Step [20/338], Loss: 0.0001
# Epoch [25/32], Step [30/338], Loss: 0.0003
# Epoch [25/32], Step [40/338], Loss: 0.0001
# Epoch [25/32], Step [50/338], Loss: 0.0167
# Epoch [25/32], Step [60/338], Loss: 0.0043
# Epoch [25/32], Step [70/338], Loss: 0.0020
# Epoch [25/32], Step [80/338], Loss: 0.0001
# Epoch [25/32], Step [90/338], Loss: 0.0010
# Epoch [25/32], Step [100/338], Loss: 0.0002
# Epoch [25/32], Step [110/338], Loss: 0.0014
# Epoch [25/32], Step [120/338], Loss: 0.0005
# Epoch [25/32], Step [130/338], Loss: 0.0008
# Epoch [25/32], Step [140/338], Loss: 0.0039
# Epoch [25/32], Step [150/338], Loss: 0.0014
# Epoch [25/32], Step [160/338], Loss: 0.0635
# Epoch [25/32], Step [170/338], Loss: 0.0013
# Epoch [25/32], Step [180/338], Loss: 0.0013
# Epoch [25/32], Step [190/338], Loss: 0.0001
# Epoch [25/32], Step [200/338], Loss: 0.0003
# Epoch [25/32], Step [210/338], Loss: 0.0002
# Epoch [25/32], Step [220/338], Loss: 0.0001
# Epoch [25/32], Step [230/338], Loss: 0.0296
# Epoch [25/32], Step [240/338], Loss: 0.0001
# Epoch [25/32], Step [250/338], Loss: 0.0046
# Epoch [25/32], Step [260/338], Loss: 0.0039
# Epoch [25/32], Step [270/338], Loss: 0.0002
# Epoch [25/32], Step [280/338], Loss: 0.0004
# Epoch [25/32], Step [290/338], Loss: 0.0003
# Epoch [25/32], Step [300/338], Loss: 0.0001
# Epoch [25/32], Step [310/338], Loss: 0.0001
# Epoch [25/32], Step [320/338], Loss: 0.0002
# Epoch [25/32], Step [330/338], Loss: 0.0004
#
# train-loss: 0.0287, train-acc: 99.7040
# validation loss: 0.5010, validation acc: 78.0338
#
# Epoch 26
#
# Epoch [26/32], Step [0/338], Loss: 0.0001
# Epoch [26/32], Step [10/338], Loss: 0.0039
# Epoch [26/32], Step [20/338], Loss: 0.0003
# Epoch [26/32], Step [30/338], Loss: 0.0048
# Epoch [26/32], Step [40/338], Loss: 0.0002
# Epoch [26/32], Step [50/338], Loss: 0.0002
# Epoch [26/32], Step [60/338], Loss: 0.0001
# Epoch [26/32], Step [70/338], Loss: 0.0001
# Epoch [26/32], Step [80/338], Loss: 0.0025
# Epoch [26/32], Step [90/338], Loss: 0.0012
# Epoch [26/32], Step [100/338], Loss: 0.0024
# Epoch [26/32], Step [110/338], Loss: 0.0001
# Epoch [26/32], Step [120/338], Loss: 0.0007
# Epoch [26/32], Step [130/338], Loss: 0.0000
# Epoch [26/32], Step [140/338], Loss: 0.0002
# Epoch [26/32], Step [150/338], Loss: 0.0000
# Epoch [26/32], Step [160/338], Loss: 0.0004
# Epoch [26/32], Step [170/338], Loss: 0.0000
# Epoch [26/32], Step [180/338], Loss: 0.0002
# Epoch [26/32], Step [190/338], Loss: 0.0013
# Epoch [26/32], Step [200/338], Loss: 0.0002
# Epoch [26/32], Step [210/338], Loss: 0.0294
# Epoch [26/32], Step [220/338], Loss: 0.0001
# Epoch [26/32], Step [230/338], Loss: 0.0013
# Epoch [26/32], Step [240/338], Loss: 0.0012
# Epoch [26/32], Step [250/338], Loss: 0.0007
# Epoch [26/32], Step [260/338], Loss: 0.0001
# Epoch [26/32], Step [270/338], Loss: 0.0005
# Epoch [26/32], Step [280/338], Loss: 0.0003
# Epoch [26/32], Step [290/338], Loss: 0.0002
# Epoch [26/32], Step [300/338], Loss: 0.0003
# Epoch [26/32], Step [310/338], Loss: 0.0002
# Epoch [26/32], Step [320/338], Loss: 0.0001
# Epoch [26/32], Step [330/338], Loss: 0.0000
#
# train-loss: 0.0280, train-acc: 99.5930
# validation loss: 0.4924, validation acc: 85.4071
#
# Improvement-Detected, save-model
# Epoch 27
#
# Epoch [27/32], Step [0/338], Loss: 0.0064
# Epoch [27/32], Step [10/338], Loss: 0.0000
# Epoch [27/32], Step [20/338], Loss: 0.0019
# Epoch [27/32], Step [30/338], Loss: 0.0002
# Epoch [27/32], Step [40/338], Loss: 0.0001
# Epoch [27/32], Step [50/338], Loss: 0.0008
# Epoch [27/32], Step [60/338], Loss: 0.0058
# Epoch [27/32], Step [70/338], Loss: 0.0046
# Epoch [27/32], Step [80/338], Loss: 0.0024
# Epoch [27/32], Step [90/338], Loss: 0.0004
# Epoch [27/32], Step [100/338], Loss: 0.0001
# Epoch [27/32], Step [110/338], Loss: 0.0004
# Epoch [27/32], Step [120/338], Loss: 0.0001
# Epoch [27/32], Step [130/338], Loss: 0.0000
# Epoch [27/32], Step [140/338], Loss: 0.0002
# Epoch [27/32], Step [150/338], Loss: 0.0002
# Epoch [27/32], Step [160/338], Loss: 0.0006
# Epoch [27/32], Step [170/338], Loss: 0.0005
# Epoch [27/32], Step [180/338], Loss: 0.0002
# Epoch [27/32], Step [190/338], Loss: 0.0000
# Epoch [27/32], Step [200/338], Loss: 0.0010
# Epoch [27/32], Step [210/338], Loss: 0.0005
# Epoch [27/32], Step [220/338], Loss: 0.0003
# Epoch [27/32], Step [230/338], Loss: 0.0025
# Epoch [27/32], Step [240/338], Loss: 0.0005
# Epoch [27/32], Step [250/338], Loss: 0.0003
# Epoch [27/32], Step [260/338], Loss: 0.0008
# Epoch [27/32], Step [270/338], Loss: 0.0019
# Epoch [27/32], Step [280/338], Loss: 0.0014
# Epoch [27/32], Step [290/338], Loss: 0.0016
# Epoch [27/32], Step [300/338], Loss: 0.4558
# Epoch [27/32], Step [310/338], Loss: 0.0004
# Epoch [27/32], Step [320/338], Loss: 0.0001
# Epoch [27/32], Step [330/338], Loss: 0.0021
#
# train-loss: 0.0271, train-acc: 99.9630
# validation loss: 0.4826, validation acc: 87.0968
#
# Improvement-Detected, save-model
# Epoch 28
#
# Epoch [28/32], Step [0/338], Loss: 0.0012
# Epoch [28/32], Step [10/338], Loss: 0.0013
# Epoch [28/32], Step [20/338], Loss: 0.0016
# Epoch [28/32], Step [30/338], Loss: 0.0004
# Epoch [28/32], Step [40/338], Loss: 0.0015
# Epoch [28/32], Step [50/338], Loss: 0.0002
# Epoch [28/32], Step [60/338], Loss: 0.0004
# Epoch [28/32], Step [70/338], Loss: 0.0108
# Epoch [28/32], Step [80/338], Loss: 0.0002
# Epoch [28/32], Step [90/338], Loss: 0.0003
# Epoch [28/32], Step [100/338], Loss: 0.0003
# Epoch [28/32], Step [110/338], Loss: 0.0003
# Epoch [28/32], Step [120/338], Loss: 0.0170
# Epoch [28/32], Step [130/338], Loss: 0.0203
# Epoch [28/32], Step [140/338], Loss: 0.0001
# Epoch [28/32], Step [150/338], Loss: 0.0016
# Epoch [28/32], Step [160/338], Loss: 0.0013
# Epoch [28/32], Step [170/338], Loss: 0.0299
# Epoch [28/32], Step [180/338], Loss: 0.0001
# Epoch [28/32], Step [190/338], Loss: 0.0003
# Epoch [28/32], Step [200/338], Loss: 0.0018
# Epoch [28/32], Step [210/338], Loss: 0.0063
# Epoch [28/32], Step [220/338], Loss: 0.0013
# Epoch [28/32], Step [230/338], Loss: 0.0017
# Epoch [28/32], Step [240/338], Loss: 0.0032
# Epoch [28/32], Step [250/338], Loss: 0.0030
# Epoch [28/32], Step [260/338], Loss: 0.0004
# Epoch [28/32], Step [270/338], Loss: 0.0001
# Epoch [28/32], Step [280/338], Loss: 0.0000
# Epoch [28/32], Step [290/338], Loss: 0.0020
# Epoch [28/32], Step [300/338], Loss: 0.0003
# Epoch [28/32], Step [310/338], Loss: 0.1576
# Epoch [28/32], Step [320/338], Loss: 0.0014
# Epoch [28/32], Step [330/338], Loss: 0.0022
#
# train-loss: 0.0264, train-acc: 99.8520
# validation loss: 0.4845, validation acc: 77.8802
#
# Epoch 29
#
# Epoch [29/32], Step [0/338], Loss: 0.0001
# Epoch [29/32], Step [10/338], Loss: 0.0014
# Epoch [29/32], Step [20/338], Loss: 0.0004
# Epoch [29/32], Step [30/338], Loss: 0.0003
# Epoch [29/32], Step [40/338], Loss: 0.0003
# Epoch [29/32], Step [50/338], Loss: 0.0002
# Epoch [29/32], Step [60/338], Loss: 0.0002
# Epoch [29/32], Step [70/338], Loss: 0.0000
# Epoch [29/32], Step [80/338], Loss: 0.0003
# Epoch [29/32], Step [90/338], Loss: 0.0019
# Epoch [29/32], Step [100/338], Loss: 0.0003
# Epoch [29/32], Step [110/338], Loss: 0.0001
# Epoch [29/32], Step [120/338], Loss: 0.0059
# Epoch [29/32], Step [130/338], Loss: 0.0001
# Epoch [29/32], Step [140/338], Loss: 0.0001
# Epoch [29/32], Step [150/338], Loss: 0.0002
# Epoch [29/32], Step [160/338], Loss: 0.0001
# Epoch [29/32], Step [170/338], Loss: 0.0021
# Epoch [29/32], Step [180/338], Loss: 0.0015
# Epoch [29/32], Step [190/338], Loss: 0.0003
# Epoch [29/32], Step [200/338], Loss: 0.0005
# Epoch [29/32], Step [210/338], Loss: 0.0004
# Epoch [29/32], Step [220/338], Loss: 0.0042
# Epoch [29/32], Step [230/338], Loss: 0.0001
# Epoch [29/32], Step [240/338], Loss: 0.0007
# Epoch [29/32], Step [250/338], Loss: 0.0001
# Epoch [29/32], Step [260/338], Loss: 0.0095
# Epoch [29/32], Step [270/338], Loss: 0.0000
# Epoch [29/32], Step [280/338], Loss: 0.0001
# Epoch [29/32], Step [290/338], Loss: 0.0009
# Epoch [29/32], Step [300/338], Loss: 0.0043
# Epoch [29/32], Step [310/338], Loss: 0.0001
# Epoch [29/32], Step [320/338], Loss: 0.0003
# Epoch [29/32], Step [330/338], Loss: 0.0027
#
# train-loss: 0.0256, train-acc: 100.0000
# validation loss: 0.4823, validation acc: 80.0307
#
# Epoch 30
#
# Epoch [30/32], Step [0/338], Loss: 0.0001
# Epoch [30/32], Step [10/338], Loss: 0.0003
# Epoch [30/32], Step [20/338], Loss: 0.0031
# Epoch [30/32], Step [30/338], Loss: 0.0012
# Epoch [30/32], Step [40/338], Loss: 0.0030
# Epoch [30/32], Step [50/338], Loss: 0.0009
# Epoch [30/32], Step [60/338], Loss: 0.0025
# Epoch [30/32], Step [70/338], Loss: 0.0005
# Epoch [30/32], Step [80/338], Loss: 0.0088
# Epoch [30/32], Step [90/338], Loss: 0.0019
# Epoch [30/32], Step [100/338], Loss: 0.0964
# Epoch [30/32], Step [110/338], Loss: 0.0012
# Epoch [30/32], Step [120/338], Loss: 0.0001
# Epoch [30/32], Step [130/338], Loss: 0.0018
# Epoch [30/32], Step [140/338], Loss: 0.0004
# Epoch [30/32], Step [150/338], Loss: 0.0004
# Epoch [30/32], Step [160/338], Loss: 0.0631
# Epoch [30/32], Step [170/338], Loss: 0.0006
# Epoch [30/32], Step [180/338], Loss: 0.0001
# Epoch [30/32], Step [190/338], Loss: 0.0021
# Epoch [30/32], Step [200/338], Loss: 0.0001
# Epoch [30/32], Step [210/338], Loss: 0.0033
# Epoch [30/32], Step [220/338], Loss: 0.0011
# Epoch [30/32], Step [230/338], Loss: 0.0003
# Epoch [30/32], Step [240/338], Loss: 0.0017
# Epoch [30/32], Step [250/338], Loss: 0.0010
# Epoch [30/32], Step [260/338], Loss: 0.0000
# Epoch [30/32], Step [270/338], Loss: 0.0001
# Epoch [30/32], Step [280/338], Loss: 0.0001
# Epoch [30/32], Step [290/338], Loss: 0.0002
# Epoch [30/32], Step [300/338], Loss: 0.0002
# Epoch [30/32], Step [310/338], Loss: 0.0001
# Epoch [30/32], Step [320/338], Loss: 0.0013
# Epoch [30/32], Step [330/338], Loss: 0.0001
#
# train-loss: 0.0250, train-acc: 99.9260
# validation loss: 0.4922, validation acc: 73.4255
#
# Epoch 31
#
# Epoch [31/32], Step [0/338], Loss: 0.0011
# Epoch [31/32], Step [10/338], Loss: 0.0044
# Epoch [31/32], Step [20/338], Loss: 0.0000
# Epoch [31/32], Step [30/338], Loss: 0.0000
# Epoch [31/32], Step [40/338], Loss: 0.0001
# Epoch [31/32], Step [50/338], Loss: 0.0001
# Epoch [31/32], Step [60/338], Loss: 0.0001
# Epoch [31/32], Step [70/338], Loss: 0.0001
# Epoch [31/32], Step [80/338], Loss: 0.0002
# Epoch [31/32], Step [90/338], Loss: 0.0012
# Epoch [31/32], Step [100/338], Loss: 0.0028
# Epoch [31/32], Step [110/338], Loss: 0.0279
# Epoch [31/32], Step [120/338], Loss: 0.0010
# Epoch [31/32], Step [130/338], Loss: 0.0006
# Epoch [31/32], Step [140/338], Loss: 0.0001
# Epoch [31/32], Step [150/338], Loss: 0.0029
# Epoch [31/32], Step [160/338], Loss: 0.0025
# Epoch [31/32], Step [170/338], Loss: 0.0195
# Epoch [31/32], Step [180/338], Loss: 0.0031
# Epoch [31/32], Step [190/338], Loss: 0.0000
# Epoch [31/32], Step [200/338], Loss: 0.0155
# Epoch [31/32], Step [210/338], Loss: 0.0000
# Epoch [31/32], Step [220/338], Loss: 0.0018
# Epoch [31/32], Step [230/338], Loss: 0.0001
# Epoch [31/32], Step [240/338], Loss: 0.0052
# Epoch [31/32], Step [250/338], Loss: 0.0001
# Epoch [31/32], Step [260/338], Loss: 0.0003
# Epoch [31/32], Step [270/338], Loss: 0.0003
# Epoch [31/32], Step [280/338], Loss: 0.0005
# Epoch [31/32], Step [290/338], Loss: 0.0000
# Epoch [31/32], Step [300/338], Loss: 0.0002
# Epoch [31/32], Step [310/338], Loss: 0.0000
# Epoch [31/32], Step [320/338], Loss: 0.0012
# Epoch [31/32], Step [330/338], Loss: 0.0000
#
# train-loss: 0.0242, train-acc: 100.0000
# validation loss: 0.4995, validation acc: 76.1905
#
# Epoch 32
#
# Epoch [32/32], Step [0/338], Loss: 0.0000
# Epoch [32/32], Step [10/338], Loss: 0.0002
# Epoch [32/32], Step [20/338], Loss: 0.0003
# Epoch [32/32], Step [30/338], Loss: 0.0003
# Epoch [32/32], Step [40/338], Loss: 0.0049
# Epoch [32/32], Step [50/338], Loss: 0.0000
# Epoch [32/32], Step [60/338], Loss: 0.0000
# Epoch [32/32], Step [70/338], Loss: 0.0003
# Epoch [32/32], Step [80/338], Loss: 0.0002
# Epoch [32/32], Step [90/338], Loss: 0.0001
# Epoch [32/32], Step [100/338], Loss: 0.0134
# Epoch [32/32], Step [110/338], Loss: 0.0002
# Epoch [32/32], Step [120/338], Loss: 0.0015
# Epoch [32/32], Step [130/338], Loss: 0.0002
# Epoch [32/32], Step [140/338], Loss: 0.0091
# Epoch [32/32], Step [150/338], Loss: 0.0005
# Epoch [32/32], Step [160/338], Loss: 0.0004
# Epoch [32/32], Step [170/338], Loss: 0.0011
# Epoch [32/32], Step [180/338], Loss: 0.0000
# Epoch [32/32], Step [190/338], Loss: 0.0009
# Epoch [32/32], Step [200/338], Loss: 0.0012
# Epoch [32/32], Step [210/338], Loss: 0.0002
# Epoch [32/32], Step [220/338], Loss: 0.0031
# Epoch [32/32], Step [230/338], Loss: 0.0016
# Epoch [32/32], Step [240/338], Loss: 0.0025
# Epoch [32/32], Step [250/338], Loss: 0.0001
# Epoch [32/32], Step [260/338], Loss: 0.0011
# Epoch [32/32], Step [270/338], Loss: 0.0003
# Epoch [32/32], Step [280/338], Loss: 0.0002
# Epoch [32/32], Step [290/338], Loss: 0.0003
# Epoch [32/32], Step [300/338], Loss: 0.0000
# Epoch [32/32], Step [310/338], Loss: 0.0004
# Epoch [32/32], Step [320/338], Loss: 0.0001
# Epoch [32/32], Step [330/338], Loss: 0.0014
#
# train-loss: 0.0236, train-acc: 99.8890
# validation loss: 0.4979, validation acc: 79.4163

# %%
fig = plt.figure()
fig.set_figheight(6)
fig.set_figwidth(13)

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'bx-', label = 'train')
plt.plot(val_loss, 'gx-', label = 'val')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc = 'upper left')

plt.subplot(1, 2, 2)
plt.plot(train_acc, 'bx-', label = 'train')
plt.plot(val_acc, 'gx-', label = 'val')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc = 'upper left')


fig.suptitle('Mobile Netv2 [Accuracy - Loss Plots]')
plt.show()

# %% [markdown]
# ### Predictions

# %% [markdown]
# #### Test

# %%
model_mobv2 = mobileNet
model_mobv2.load_state_dict(torch.load(path_res))


print('Test data: ')
y_true = []
y_pred = []

for i in range(len(test_dataset)):
    input, target = test_dataset[i][0], test_dataset[i][1]
    model_mobv2.eval()
    with torch.no_grad():
        input = torch.unsqueeze(input, 0)
        input = input.to(device) # send data to GPU 
        predictions = model_mobv2(input)
        predicted_index = predictions[0].argmax(0)

        predicted = class_mapping[predicted_index]
        expected = class_mapping[target]

    y_true.append(expected)
    y_pred.append(predicted)

get_metrics(y_true, y_pred, class_mapping)
# Out:
# Test data:
# ┌──────────────────┬─────────┬──────────────┬──────────────┬──────────────┐
# │                  │ healthy │ misalignment │ rotor damage │ Total actual │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ healthy          │ 122     │ 0            │ 84           │ 206          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ misalignment     │ 0       │ 229          │ 0            │ 229          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ rotor damage     │ 0       │ 0            │ 216          │ 216          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ Total predicted: │ 122     │ 229          │ 300          │ 651          │
# └──────────────────┴─────────┴──────────────┴──────────────┴──────────────┘
#
# ┌──────────────┬──────────┐
# │ Class        │ F1-score │
# ├──────────────┼──────────┤
# │ Healthy      │ 0.74     │
# ├──────────────┼──────────┤
# │ Misalignment │ 1.0      │
# ├──────────────┼──────────┤
# │ Rotor damage │ 0.84     │
# └──────────────┴──────────┘
#
# Recall for healthy class: 1.0
# Recall for misalignment class: 1.0
# Recall for rotor damage class: 0.72
#
# Precision for healthy class: 0.59
# Precision for misalignment class: 1.0
# Precision for rotor damage class: 1.0

# %% [markdown]
# #### Validation

# %%
print('Valid data: ')
y_true = []
y_pred = []

for i in range(len(val_dataset)):
    input, target = val_dataset[i][0], val_dataset[i][1]
    model_mobv2.eval()
    with torch.no_grad():
        input = torch.unsqueeze(input, 0)
        input = input.to(device) # send data to GPU 
        predictions = model_mobv2(input)
        predicted_index = predictions[0].argmax(0)

        predicted = class_mapping[predicted_index]
        expected = class_mapping[target]

    y_true.append(expected)
    y_pred.append(predicted)

get_metrics(y_true, y_pred, class_mapping)
# Out:
# Valid data:
# ┌──────────────────┬─────────┬──────────────┬──────────────┬──────────────┐
# │                  │ healthy │ misalignment │ rotor damage │ Total actual │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ healthy          │ 188     │ 0            │ 11           │ 199          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ misalignment     │ 0       │ 220          │ 0            │ 220          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ rotor damage     │ 0       │ 0            │ 229          │ 229          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ Total predicted: │ 188     │ 220          │ 240          │ 648          │
# └──────────────────┴─────────┴──────────────┴──────────────┴──────────────┘
#
# ┌──────────────┬──────────┐
# │ Class        │ F1-score │
# ├──────────────┼──────────┤
# │ Healthy      │ 0.97     │
# ├──────────────┼──────────┤
# │ Misalignment │ 1.0      │
# ├──────────────┼──────────┤
# │ Rotor damage │ 0.98     │
# └──────────────┴──────────┘
#
# Recall for healthy class: 1.0
# Recall for misalignment class: 1.0
# Recall for rotor damage class: 0.95
#
# Precision for healthy class: 0.94
# Precision for misalignment class: 1.0
# Precision for rotor damage class: 1.0

# %% [markdown]
# #### Training

# %%
print('Training data:')
y_true = []
y_pred = []

for i in range(len(train_dataset)):
    input, target = train_dataset[i][0], train_dataset[i][1]
    model_mobv2.eval()
    with torch.no_grad():
        input = torch.unsqueeze(input, 0)
        input = input.to(device) # send data to GPU
        predictions = model_mobv2(input)
        predicted_index = predictions[0].argmax(0)

        predicted = class_mapping[predicted_index]
        expected = class_mapping[target]

    y_true.append(expected)
    y_pred.append(predicted)

get_metrics(y_true, y_pred, class_mapping)
# Out:
# Training data:
# ┌──────────────────┬─────────┬──────────────┬──────────────┬──────────────┐
# │                  │ healthy │ misalignment │ rotor damage │ Total actual │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ healthy          │ 557     │ 0            │ 0            │ 557          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ misalignment     │ 0       │ 981          │ 0            │ 981          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ rotor damage     │ 0       │ 0            │ 1165         │ 1165         │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ Total predicted: │ 557     │ 981          │ 1165         │ 2703         │
# └──────────────────┴─────────┴──────────────┴──────────────┴──────────────┘
#
# ┌──────────────┬──────────┐
# │ Class        │ F1-score │
# ├──────────────┼──────────┤
# │ Healthy      │ 1.0      │
# ├──────────────┼──────────┤
# │ Misalignment │ 1.0      │
# ├──────────────┼──────────┤
# │ Rotor damage │ 1.0      │
# └──────────────┴──────────┘
#
# Recall for healthy class: 1.0
# Recall for misalignment class: 1.0
# Recall for rotor damage class: 1.0
#
# Precision for healthy class: 1.0
# Precision for misalignment class: 1.0
# Precision for rotor damage class: 1.0

# %% [markdown]
# ### Different Style of Training

# %%
# n_epochs = 20
# print_every = 10
# valid_loss_min = np.Inf
# val_loss = []
# val_acc = []
# train_loss = []
# train_acc = []
# total_step = len(train_loader)
# for epoch in range(1, n_epochs+1):
#     running_loss = 0.0
#     correct = 0
#     total=0
#     print(f'Epoch {epoch}\n')
#     for batch_idx, (data_, target_) in enumerate(train_loader):
#         data_, target_ = data_.to(device), target_.to(device)
#         optimizer.zero_grad()
        
#         outputs = resnet(data_)
#         loss = criterion(outputs, target_)
#         loss.backward()
#         optimizer.step()

#         running_loss += loss.item()
#         _,pred = torch.max(outputs, dim=1)
#         correct += torch.sum(pred==target_).item()
#         total += target_.size(0)
#         if (batch_idx) % 20 == 0:
#             print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
#                    .format(epoch, n_epochs, batch_idx, total_step, loss.item()))
#     train_acc.append(100 * correct / total)
#     train_loss.append(running_loss/total_step)
#     print(f'\ntrain-loss: {np.mean(train_loss):.4f}, train-acc: {(100 * correct/total):.4f}')
#     batch_loss = 0
#     total_t=0
#     correct_t=0
#     with torch.no_grad():
#         resnet.eval()
#         for data_t, target_t in (test_loader):
#             data_t, target_t = data_t.to(device), target_t.to(device)
#             outputs_t = resnet(data_t)
#             loss_t = criterion(outputs_t, target_t)
#             batch_loss += loss_t.item()
#             _,pred_t = torch.max(outputs_t, dim=1)
#             correct_t += torch.sum(pred_t==target_t).item()
#             total_t += target_t.size(0)
#         val_acc.append(100 * correct_t/total_t)
#         val_loss.append(batch_loss/len(test_loader))
#         network_learned = batch_loss < valid_loss_min
#         print(f'validation loss: {np.mean(val_loss):.4f}, validation acc: {(100 * correct_t/total_t):.4f}\n')

        
#         if network_learned:
#             valid_loss_min = batch_loss
#             torch.save(resnet.state_dict(), "C:/Users/Nihal/Desktop/thesis/resnet18_train2.pt")
#             print('Improvement-Detected, save-model')
#     resnet.train()

# %% [markdown]
# ### Train - Validation Accuracy

# %%
# fig = plt.figure(figsize=(20,10))
# plt.title("Train-Validation Accuracy")
# plt.plot(train_acc, label='train')
# plt.plot(val_acc, label='validation')
# plt.xlabel('num_epochs', fontsize=12)
# plt.ylabel('accuracy', fontsize=12)
# plt.legend(loc='best')

# %% [markdown]
# ### Visualize Results

# %%
# def visualize_model(net, num_images=4):
#     images_so_far = 0
#     fig = plt.figure(figsize=(15, 10))
    
#     for i, data in enumerate(test_dataloader):
#         inputs, labels = data
#         if use_cuda:
#             inputs, labels = inputs.cuda(), labels.cuda()
#         outputs = net(inputs)
#         _, preds = torch.max(outputs.data, 1)
#         preds = preds.cpu().numpy() if use_cuda else preds.numpy()
#         for j in range(inputs.size()[0]):
#             images_so_far += 1
#             ax = plt.subplot(2, num_images//2, images_so_far)
#             ax.axis('off')
#             ax.set_title('predictes: {}'.format(test_dataset.classes[preds[j]]))
#             imshow(inputs[j])
            
#             if images_so_far == num_images:
#                 return 

# plt.ion()
# visualize_model(net)
# plt.ioff()
