# %% [markdown]
# <a href="https://colab.research.google.com/github/nihalsuri/thermal-anomaly-detection/blob/main/thermal_anomaly_detection_wide_resnet_50_2_early_stopping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Uploading all necessary data when connected to host

# %%
! gdown --id 1x4Os51uaMXDILTGo2Y_lOC9HU1jTnzi0
! gdown --id 1uxDV-sgzDUATHc5p8gW_gBKBsEVrz34x
# Out:
# 'gdown' is not recognized as an internal or external command,
# operable program or batch file.
# 'gdown' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !unzip clutch_2.zip
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Uploading data when connected to local runtime

# %%
annotations_path = 'C:/Users/Nihal/Desktop/thesis/dataset.csv'
# annotations_path = 'C:/Users/Nihal/Desktop/new_dataset.csv'
dataset_path = 'C:/Users/Nihal/Desktop/thesis/clutch_2'

# %% [markdown]
# # Data preperation for training
#
# In this section the following is done:
#
#
#
# *   Data is processed and arranged into respective **dataframes**
# *   **Custom dataset** class is created
# *   **Transforms** are done on the various datasets
# *   **Dataloaders** are created for the purposes of iteration

# %% [markdown]
# ## Import libraries

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision.utils import make_grid
from PIL import Image
from torchvision import transforms , models
from sklearn import metrics
from tabulate import tabulate
import os
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F 
import torch.optim as optim
import io
import copy
import tqdm 
import time

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device_name = torch.cuda.get_device_name()
print(device_name)
print(device)
# Out:
# NVIDIA GeForce GTX 1660 Ti with Max-Q Design
# cuda

# %%
torch.cuda.empty_cache()

# %%
torch.cuda.memory_summary(device=None, abbreviated=False)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 0            |        cudaMalloc retries: 0         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|---------------------------------------------------------------------------|\n| Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|---------------------------------------------------------------------------|\n| Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |\n|---------------------------------------------------------------------------|\n| Allocations           |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Active allocs         |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |       0    |       0    |       0    |       0    |\n|       from large pool |       0    |       0    |       0    |       0    |\n|       from small pool |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize allocations  |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize GPU segments |       0    |       0    |       0    |       0    |\n|===========================================================================|\n'

# %% [markdown]
# ## Split data into dataframes

# %%
df = pd.read_csv(annotations_path)
train_df = df[df['dataset'].str.contains('train')]
test_df = df[df['dataset'].str.contains('test')]
val_df = df[df['dataset'].str.contains('val')]
print(train_df.shape[0])
print(test_df.shape[0])
print(val_df.shape[0])
# Out:
# 2703
# 651
# 648

# %%
# img_paths = df["img_path"]

# %%
# for i in range(img_paths.shape[0]):
#   size  = len(img_paths.at[i])
#   new_path = img_paths.at[i][:size - 24]
#   img_paths.at[i] = new_path

# %%
# img_paths.head()

# %%
# unique_lables = img_paths.unique().tolist()

# %%
# df_freq = img_paths.value_counts()
# df_freq

# %% [markdown]
# ## Custom Class
# Returns **image** and **label** for futher training

# %%
class ClutchDataset(Dataset):

    def __init__(self, dataframe, root_dir, is_train, transform=None):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.transform = transform
        self.is_train = is_train

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(self.root_dir, self.dataframe.iloc[idx, 1])
        image1 = cv2.imread(img_name)
        image_norm = cv2.normalize(
            image1, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)
        image = Image.fromarray(image_norm)
        label = torch.tensor(int(self.dataframe.iloc[idx, 2]))
         


        if self.transform:
            image = self.transform(image)
        
        #image = transforms.functional.crop(image, 140, 360 , 240, 240) # take only right part of the system
        #image = transforms.functional.crop(image, 220, 460 , 160, 160) # take only right tip of the system 1 
        #image = transforms.functional.crop(image, 190, 510 , 140, 110) # more right 2
        #image = transforms.functional.crop(image, 190, 470 , 140, 140) # more right 3
        #image = transforms.functional.crop(image, 190, 440 , 140, 180) # more right 4
        #image = transforms.functional.crop(image, 190, 470 , 130, 150) # more right 5
        
        #image = transforms.functional.crop(image, 190, 285 , 140, 320) # mm
        image = transforms.functional.crop(image, 190, 380 , 140, 230)
        #image = transforms.functional.crop(image, 190, 430 , 140, 180) #6

        return image, label

# %% [markdown]
# ## Transforms on the datasets

# %%
# Add transforms for train, test, val dataset
input_size_h = 512
input_size_w = 640
transform_train = transforms.Compose([
   #transforms.Resize((input_size_h, input_size_w)),
    #transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    #transforms.RandomPerspective(),
    #transforms.RandomRotation((1, 8))

])

transform_valid = transforms.Compose([
    #transforms.Resize((input_size_h, input_size_w)),
    #transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor()
])

transform_test = transforms.Compose([
    #transforms.Resize((input_size_h, input_size_w)),
    #transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor()
])

# %% [markdown]
# ## Dataloaders and Iterator

# %%
def show_batch(dl):
    """Plot images grid of single batch"""
    for images, labels in dl:
        fig,ax = plt.subplots(figsize = (16,12))
        ax.set_xticks([])
        ax.set_yticks([])
        ax.imshow(make_grid(images,nrow=16).permute(1,2,0))
        break



# dataloaders
train_dataset = ClutchDataset(
    train_df, root_dir=dataset_path, is_train=True, transform=transform_train)
val_dataset = ClutchDataset(val_df, root_dir=dataset_path,
                            is_train=False, transform=transform_valid)
test_dataset = ClutchDataset(
    test_df, root_dir=dataset_path, is_train=False, transform=transform_test)

train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

dataloaders_dict = {}
dataloaders_dict['train'] = train_loader
dataloaders_dict['val'] = val_loader
dataloaders_dict['test'] = test_loader


# iteratre through dataloaders
train_features, train_labels = next(iter(train_loader))
print(f"Feature batch shape: {train_features.shape}")
print(f"Labels batch shape: {train_labels.shape}")
img = train_features[0].squeeze()
label = train_labels[0]

# convert image to APPEAR RGB
# rgb_train_features = np.repeat(train_features[..., np.newaxis], 3, -1)
# print(f"Feature batch shape: {rgb_train_features.shape}")
# train_features = rgb_train_features

# plt.imshow(img, cmap="gray")
# plt.axis('off')
# plt.show()
# print(f"Label: {label}")
show_batch(train_loader)
# Out:
# Feature batch shape: torch.Size([8, 3, 140, 230])
# Labels batch shape: torch.Size([8])

# %% [markdown]
# # Neural Networks
# Various different NNs tested with the same dataset

# %% [markdown]
# ### Metrics

# %%
def get_metrics(y_true, y_pred, class_mapping):

    total_predictions = [0, 0, 0]
    total_true = [0, 0, 0]

    cm = metrics.confusion_matrix(y_true, y_pred, labels=class_mapping)

    for i in range(3):
        for j in range(3):
            total_predictions[i] += cm[j][i]
            total_true[i] += cm[i][j]

    # recall and precision for each class
    r_h = cm[0][0] / total_predictions[0]
    r_m = cm[1][1] / total_predictions[1]
    r_r = cm[2][2] / total_predictions[2]
    p_h = cm[0][0] / total_true[0]
    p_m = cm[1][1] / total_true[1]
    p_r = cm[2][2] / total_true[2]

    # data for confusion matrix
    data = [["", class_mapping[0], class_mapping[1], class_mapping[2], "Total actual"],
            [class_mapping[0], cm[0][0], cm[0][1], cm[0][2], total_true[0]],
            [class_mapping[1], cm[1][0], cm[1][1], cm[1][2], total_true[1]],
            [class_mapping[2], cm[2][0], cm[2][1], cm[2][2], total_true[2]],
            ["Total predicted:", total_predictions[0], total_predictions[1], total_predictions[2], sum(total_true)]]

    # data for f1 score for each class
    data_f1 = [["Class", "F1-score"],
               ["Healthy", round((2 * p_h * r_h) / (p_h + r_h), 2)],
               ["Misalignment", round((2 * p_m * r_m) / (p_m + r_m), 2)],
               ["Rotor damage", round((2 * p_r * r_r) / (p_r + r_r), 2)]]

    # printing confusion matrix, f1 score table, recall and precision
    print(tabulate(data, tablefmt="simple_grid"))
    print()
    print(tabulate(data_f1, tablefmt="simple_grid"))
    print(f"\nRecall for healthy class: {round(r_h, 2)}")
    print(f"Recall for misalignment class: {round(r_m, 2)}")
    print(f"Recall for rotor damage class: {round(r_r, 2)}")
    print(f"\nPrecision for healthy class: {round(p_h, 2)}")
    print(f"Precision for misalignment class: {round(p_m, 2)}")
    print(f"Precision for rotor damage class: {round(p_r, 2)}")

# %% [markdown]
# ## Wide Resnet 50-2( Transfer Learning )
#
# With the resnet152 architecture instead of developing the DNN(Dense Neural Network) on our own we take a **transfer learning approach**, so the **classification** block will be modified and the input into the first **convolutional block** will be made to look-like its 3-channel as the pretrained model accepts ony 3-channel images, this is done by taking the same grayscale image and mapping it onto the three axes.

# %% [markdown]
# ### Pretrained Model

# %%
resnet = models.wide_resnet50_2(pretrained=True)
resnet = resnet.cuda() if device else resnet
resnet
# Out:
# c:\users\nihal\appdata\local\programs\python\python37\lib\site-packages\torchvision\models\_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# c:\users\nihal\appdata\local\programs\python\python37\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Wide_ResNet50_2_Weights.IMAGENET1K_V1`. You can also use `weights=Wide_ResNet50_2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %% [markdown]
# ### Changes to pretrained model to fit dataset

# %%
num_ftrs = resnet.fc.in_features
resnet.fc = nn.Linear(num_ftrs, 3)
resnet.fc = resnet.fc.cuda() 
resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=3, bias=True)
# )

# %% [markdown]
# ### Hyperparameters

# %%
path_res = "C:/Users/Nihal/Desktop/thesis/wide-resnet-50-2-es-20ep.pt"
LEARNING_RATE = 0.0001

loss_val = []
train_acc = []
class_mapping = ['healthy', 'misalignment', 'rotor damage']

# %% [markdown]
# ### Training per epoch

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(resnet.parameters(), lr=LEARNING_RATE, momentum=0.9)
n_epochs = 32
print_every = 10
valid_loss_min = np.Inf
val_loss = []
val_acc = []
train_loss = []
train_acc = []
total_step = len(train_loader)
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
    correct = 0
    total=0
    print(f'Epoch {epoch}\n')
    for batch_idx, (data_, target_) in enumerate(train_loader):
        data_, target_ = data_.to(device), target_.to(device)
        optimizer.zero_grad()
        
        outputs = resnet(data_)
        loss = criterion(outputs, target_)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _,pred = torch.max(outputs, dim=1)
        correct += torch.sum(pred==target_).item()
        total += target_.size(0)
        if (batch_idx) % 10 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch, n_epochs, batch_idx, total_step, loss.item()))
    train_acc.append(100 * correct / total)
    train_loss.append(running_loss/total_step)
    print(f'\ntrain-loss: {np.mean(train_loss):.4f}, train-acc: {(100 * correct/total):.4f}')
    batch_loss = 0
    total_t=0
    correct_t=0
    with torch.no_grad():
        resnet.eval()
        for data_t, target_t in (test_loader):
            data_t, target_t = data_t.to(device), target_t.to(device)
            outputs_t =resnet(data_t)
            loss_t = criterion(outputs_t, target_t)
            batch_loss += loss_t.item()
            _,pred_t = torch.max(outputs_t, dim=1)
            correct_t += torch.sum(pred_t==target_t).item()
            total_t += target_t.size(0)
        val_acc.append(100 * correct_t/total_t)
        val_loss.append(batch_loss/len(test_loader))
        network_learned = batch_loss < valid_loss_min
        print(f'validation loss: {np.mean(val_loss):.4f}, validation acc: {(100 * correct_t/total_t):.4f}\n')

        
        if network_learned:
            valid_loss_min = batch_loss
            torch.save(resnet.state_dict(), path_res)
            print('Improvement-Detected, save-model')
    resnet.train()
# Out:
# Epoch 1
#
# Epoch [1/32], Step [0/338], Loss: 1.0880
# Epoch [1/32], Step [10/338], Loss: 1.0587
# Epoch [1/32], Step [20/338], Loss: 1.0478
# Epoch [1/32], Step [30/338], Loss: 0.7229
# Epoch [1/32], Step [40/338], Loss: 0.9617
# Epoch [1/32], Step [50/338], Loss: 0.6913
# Epoch [1/32], Step [60/338], Loss: 0.7056
# Epoch [1/32], Step [70/338], Loss: 0.6088
# Epoch [1/32], Step [80/338], Loss: 0.5166
# Epoch [1/32], Step [90/338], Loss: 1.0946
# Epoch [1/32], Step [100/338], Loss: 0.6986
# Epoch [1/32], Step [110/338], Loss: 0.3524
# Epoch [1/32], Step [120/338], Loss: 0.6765
# Epoch [1/32], Step [130/338], Loss: 0.3764
# Epoch [1/32], Step [140/338], Loss: 0.3265
# Epoch [1/32], Step [150/338], Loss: 0.2993
# Epoch [1/32], Step [160/338], Loss: 0.2417
# Epoch [1/32], Step [170/338], Loss: 0.2263
# Epoch [1/32], Step [180/338], Loss: 0.2448
# Epoch [1/32], Step [190/338], Loss: 0.1732
# Epoch [1/32], Step [200/338], Loss: 0.2786
# Epoch [1/32], Step [210/338], Loss: 0.1653
# Epoch [1/32], Step [220/338], Loss: 0.7966
# Epoch [1/32], Step [230/338], Loss: 0.0822
# Epoch [1/32], Step [240/338], Loss: 0.1982
# Epoch [1/32], Step [250/338], Loss: 0.1008
# Epoch [1/32], Step [260/338], Loss: 0.0996
# Epoch [1/32], Step [270/338], Loss: 0.2486
# Epoch [1/32], Step [280/338], Loss: 0.1145
# Epoch [1/32], Step [290/338], Loss: 0.1446
# Epoch [1/32], Step [300/338], Loss: 0.0645
# Epoch [1/32], Step [310/338], Loss: 0.0840
# Epoch [1/32], Step [320/338], Loss: 0.0955
# Epoch [1/32], Step [330/338], Loss: 0.0391
#
# train-loss: 0.3980, train-acc: 91.1580
# validation loss: 0.4100, validation acc: 73.2719
#
# Improvement-Detected, save-model
# Epoch 2
#
# Epoch [2/32], Step [0/338], Loss: 0.1915
# Epoch [2/32], Step [10/338], Loss: 0.0753
# Epoch [2/32], Step [20/338], Loss: 0.0593
# Epoch [2/32], Step [30/338], Loss: 0.1806
# Epoch [2/32], Step [40/338], Loss: 0.0392
# Epoch [2/32], Step [50/338], Loss: 0.3334
# Epoch [2/32], Step [60/338], Loss: 0.0848
# Epoch [2/32], Step [70/338], Loss: 0.0401
# Epoch [2/32], Step [80/338], Loss: 0.5799
# Epoch [2/32], Step [90/338], Loss: 0.0668
# Epoch [2/32], Step [100/338], Loss: 0.1227
# Epoch [2/32], Step [110/338], Loss: 0.0819
# Epoch [2/32], Step [120/338], Loss: 0.0661
# Epoch [2/32], Step [130/338], Loss: 0.0163
# Epoch [2/32], Step [140/338], Loss: 0.0239
# Epoch [2/32], Step [150/338], Loss: 0.0241
# Epoch [2/32], Step [160/338], Loss: 0.0632
# Epoch [2/32], Step [170/338], Loss: 0.0959
# Epoch [2/32], Step [180/338], Loss: 0.0227
# Epoch [2/32], Step [190/338], Loss: 0.1173
# Epoch [2/32], Step [200/338], Loss: 0.0291
# Epoch [2/32], Step [210/338], Loss: 0.2306
# Epoch [2/32], Step [220/338], Loss: 0.0423
# Epoch [2/32], Step [230/338], Loss: 0.0320
# Epoch [2/32], Step [240/338], Loss: 0.0223
# Epoch [2/32], Step [250/338], Loss: 0.0409
# Epoch [2/32], Step [260/338], Loss: 0.0316
# Epoch [2/32], Step [270/338], Loss: 0.0282
# Epoch [2/32], Step [280/338], Loss: 0.1212
# Epoch [2/32], Step [290/338], Loss: 0.0496
# Epoch [2/32], Step [300/338], Loss: 0.0557
# Epoch [2/32], Step [310/338], Loss: 0.0664
# Epoch [2/32], Step [320/338], Loss: 0.4675
# Epoch [2/32], Step [330/338], Loss: 0.2578
#
# train-loss: 0.2432, train-acc: 99.1491
# validation loss: 0.3418, validation acc: 88.1720
#
# Improvement-Detected, save-model
# Epoch 3
#
# Epoch [3/32], Step [0/338], Loss: 0.0399
# Epoch [3/32], Step [10/338], Loss: 0.0205
# Epoch [3/32], Step [20/338], Loss: 0.0137
# Epoch [3/32], Step [30/338], Loss: 0.0126
# Epoch [3/32], Step [40/338], Loss: 0.0254
# Epoch [3/32], Step [50/338], Loss: 0.0582
# Epoch [3/32], Step [60/338], Loss: 0.0574
# Epoch [3/32], Step [70/338], Loss: 0.2268
# Epoch [3/32], Step [80/338], Loss: 0.0389
# Epoch [3/32], Step [90/338], Loss: 0.0105
# Epoch [3/32], Step [100/338], Loss: 0.0080
# Epoch [3/32], Step [110/338], Loss: 0.0155
# Epoch [3/32], Step [120/338], Loss: 0.0104
# Epoch [3/32], Step [130/338], Loss: 0.0274
# Epoch [3/32], Step [140/338], Loss: 0.0288
# Epoch [3/32], Step [150/338], Loss: 0.0083
# Epoch [3/32], Step [160/338], Loss: 0.0161
# Epoch [3/32], Step [170/338], Loss: 0.0422
# Epoch [3/32], Step [180/338], Loss: 0.0563
# Epoch [3/32], Step [190/338], Loss: 0.0118
# Epoch [3/32], Step [200/338], Loss: 0.0270
# Epoch [3/32], Step [210/338], Loss: 0.0073
# Epoch [3/32], Step [220/338], Loss: 0.0589
# Epoch [3/32], Step [230/338], Loss: 0.0075
# Epoch [3/32], Step [240/338], Loss: 0.0204
# Epoch [3/32], Step [250/338], Loss: 0.0402
# Epoch [3/32], Step [260/338], Loss: 0.0095
# Epoch [3/32], Step [270/338], Loss: 0.0072
# Epoch [3/32], Step [280/338], Loss: 0.0088
# Epoch [3/32], Step [290/338], Loss: 0.1076
# Epoch [3/32], Step [300/338], Loss: 0.0115
# Epoch [3/32], Step [310/338], Loss: 0.2001
# Epoch [3/32], Step [320/338], Loss: 0.0134
# Epoch [3/32], Step [330/338], Loss: 0.0132
#
# train-loss: 0.1754, train-acc: 99.6670
# validation loss: 0.2860, validation acc: 94.7773
#
# Improvement-Detected, save-model
# Epoch 4
#
# Epoch [4/32], Step [0/338], Loss: 0.0488
# Epoch [4/32], Step [10/338], Loss: 0.0068
# Epoch [4/32], Step [20/338], Loss: 0.0100
# Epoch [4/32], Step [30/338], Loss: 0.0210
# Epoch [4/32], Step [40/338], Loss: 0.0140
# Epoch [4/32], Step [50/338], Loss: 0.0189
# Epoch [4/32], Step [60/338], Loss: 0.0097
# Epoch [4/32], Step [70/338], Loss: 0.0356
# Epoch [4/32], Step [80/338], Loss: 0.0395
# Epoch [4/32], Step [90/338], Loss: 0.0055
# Epoch [4/32], Step [100/338], Loss: 0.0058
# Epoch [4/32], Step [110/338], Loss: 0.2115
# Epoch [4/32], Step [120/338], Loss: 0.0152
# Epoch [4/32], Step [130/338], Loss: 0.0192
# Epoch [4/32], Step [140/338], Loss: 0.0111
# Epoch [4/32], Step [150/338], Loss: 0.0216
# Epoch [4/32], Step [160/338], Loss: 0.0046
# Epoch [4/32], Step [170/338], Loss: 0.0101
# Epoch [4/32], Step [180/338], Loss: 0.1807
# Epoch [4/32], Step [190/338], Loss: 0.0100
# Epoch [4/32], Step [200/338], Loss: 0.0164
# Epoch [4/32], Step [210/338], Loss: 0.0820
# Epoch [4/32], Step [220/338], Loss: 0.0206
# Epoch [4/32], Step [230/338], Loss: 0.0074
# Epoch [4/32], Step [240/338], Loss: 0.0077
# Epoch [4/32], Step [250/338], Loss: 0.0036
# Epoch [4/32], Step [260/338], Loss: 0.0034
# Epoch [4/32], Step [270/338], Loss: 0.0036
# Epoch [4/32], Step [280/338], Loss: 0.0100
# Epoch [4/32], Step [290/338], Loss: 0.0149
# Epoch [4/32], Step [300/338], Loss: 0.0199
# Epoch [4/32], Step [310/338], Loss: 0.3317
# Epoch [4/32], Step [320/338], Loss: 0.0025
# Epoch [4/32], Step [330/338], Loss: 0.0043
#
# train-loss: 0.1397, train-acc: 99.5930
# validation loss: 0.2735, validation acc: 90.4762
#
# Epoch 5
#
# Epoch [5/32], Step [0/338], Loss: 0.0242
# Epoch [5/32], Step [10/338], Loss: 0.0200
# Epoch [5/32], Step [20/338], Loss: 0.0056
# Epoch [5/32], Step [30/338], Loss: 0.0259
# Epoch [5/32], Step [40/338], Loss: 0.0149
# Epoch [5/32], Step [50/338], Loss: 0.0039
# Epoch [5/32], Step [60/338], Loss: 0.0081
# Epoch [5/32], Step [70/338], Loss: 0.0081
# Epoch [5/32], Step [80/338], Loss: 0.0068
# Epoch [5/32], Step [90/338], Loss: 0.0087
# Epoch [5/32], Step [100/338], Loss: 0.0033
# Epoch [5/32], Step [110/338], Loss: 0.0032
# Epoch [5/32], Step [120/338], Loss: 0.0082
# Epoch [5/32], Step [130/338], Loss: 0.0083
# Epoch [5/32], Step [140/338], Loss: 0.0418
# Epoch [5/32], Step [150/338], Loss: 0.1038
# Epoch [5/32], Step [160/338], Loss: 0.0093
# Epoch [5/32], Step [170/338], Loss: 0.0020
# Epoch [5/32], Step [180/338], Loss: 0.0135
# Epoch [5/32], Step [190/338], Loss: 0.0067
# Epoch [5/32], Step [200/338], Loss: 0.0383
# Epoch [5/32], Step [210/338], Loss: 0.0090
# Epoch [5/32], Step [220/338], Loss: 0.0029
# Epoch [5/32], Step [230/338], Loss: 0.0037
# Epoch [5/32], Step [240/338], Loss: 0.0031
# Epoch [5/32], Step [250/338], Loss: 0.0178
# Epoch [5/32], Step [260/338], Loss: 0.0060
# Epoch [5/32], Step [270/338], Loss: 0.0395
# Epoch [5/32], Step [280/338], Loss: 0.0055
# Epoch [5/32], Step [290/338], Loss: 0.0300
# Epoch [5/32], Step [300/338], Loss: 0.0089
# Epoch [5/32], Step [310/338], Loss: 0.0173
# Epoch [5/32], Step [320/338], Loss: 0.0759
# Epoch [5/32], Step [330/338], Loss: 0.0169
#
# train-loss: 0.1168, train-acc: 99.6300
# validation loss: 0.3006, validation acc: 76.0369
#
# Epoch 6
#
# Epoch [6/32], Step [0/338], Loss: 0.0117
# Epoch [6/32], Step [10/338], Loss: 0.0092
# Epoch [6/32], Step [20/338], Loss: 0.0177
# Epoch [6/32], Step [30/338], Loss: 0.0086
# Epoch [6/32], Step [40/338], Loss: 0.0028
# Epoch [6/32], Step [50/338], Loss: 0.0041
# Epoch [6/32], Step [60/338], Loss: 0.0020
# Epoch [6/32], Step [70/338], Loss: 0.1419
# Epoch [6/32], Step [80/338], Loss: 0.0315
# Epoch [6/32], Step [90/338], Loss: 0.0068
# Epoch [6/32], Step [100/338], Loss: 0.0046
# Epoch [6/32], Step [110/338], Loss: 0.0027
# Epoch [6/32], Step [120/338], Loss: 0.0067
# Epoch [6/32], Step [130/338], Loss: 0.0549
# Epoch [6/32], Step [140/338], Loss: 0.0027
# Epoch [6/32], Step [150/338], Loss: 0.0265
# Epoch [6/32], Step [160/338], Loss: 0.0053
# Epoch [6/32], Step [170/338], Loss: 0.0017
# Epoch [6/32], Step [180/338], Loss: 0.0116
# Epoch [6/32], Step [190/338], Loss: 0.0128
# Epoch [6/32], Step [200/338], Loss: 0.0109
# Epoch [6/32], Step [210/338], Loss: 0.0018
# Epoch [6/32], Step [220/338], Loss: 0.0017
# Epoch [6/32], Step [230/338], Loss: 0.0859
# Epoch [6/32], Step [240/338], Loss: 0.0028
# Epoch [6/32], Step [250/338], Loss: 0.0099
# Epoch [6/32], Step [260/338], Loss: 0.0014
# Epoch [6/32], Step [270/338], Loss: 0.0224
# Epoch [6/32], Step [280/338], Loss: 0.0032
# Epoch [6/32], Step [290/338], Loss: 0.0019
# Epoch [6/32], Step [300/338], Loss: 0.0098
# Epoch [6/32], Step [310/338], Loss: 0.0016
# Epoch [6/32], Step [320/338], Loss: 0.0064
# Epoch [6/32], Step [330/338], Loss: 0.0018
#
# train-loss: 0.1014, train-acc: 99.5560
# validation loss: 0.3292, validation acc: 74.0399
#
# Epoch 7
#
# Epoch [7/32], Step [0/338], Loss: 0.0018
# Epoch [7/32], Step [10/338], Loss: 0.0930
# Epoch [7/32], Step [20/338], Loss: 0.0153
# Epoch [7/32], Step [30/338], Loss: 0.0127
# Epoch [7/32], Step [40/338], Loss: 0.0016
# Epoch [7/32], Step [50/338], Loss: 0.0038
# Epoch [7/32], Step [60/338], Loss: 0.0020
# Epoch [7/32], Step [70/338], Loss: 0.0067
# Epoch [7/32], Step [80/338], Loss: 0.0155
# Epoch [7/32], Step [90/338], Loss: 0.0033
# Epoch [7/32], Step [100/338], Loss: 0.0017
# Epoch [7/32], Step [110/338], Loss: 0.0014
# Epoch [7/32], Step [120/338], Loss: 0.0080
# Epoch [7/32], Step [130/338], Loss: 0.0075
# Epoch [7/32], Step [140/338], Loss: 0.0016
# Epoch [7/32], Step [150/338], Loss: 0.0040
# Epoch [7/32], Step [160/338], Loss: 0.0017
# Epoch [7/32], Step [170/338], Loss: 0.0044
# Epoch [7/32], Step [180/338], Loss: 0.0166
# Epoch [7/32], Step [190/338], Loss: 0.0035
# Epoch [7/32], Step [200/338], Loss: 0.0036
# Epoch [7/32], Step [210/338], Loss: 0.0245
# Epoch [7/32], Step [220/338], Loss: 0.0078
# Epoch [7/32], Step [230/338], Loss: 0.0040
# Epoch [7/32], Step [240/338], Loss: 0.0158
# Epoch [7/32], Step [250/338], Loss: 0.0015
# Epoch [7/32], Step [260/338], Loss: 0.0032
# Epoch [7/32], Step [270/338], Loss: 0.0086
# Epoch [7/32], Step [280/338], Loss: 0.0027
# Epoch [7/32], Step [290/338], Loss: 0.0032
# Epoch [7/32], Step [300/338], Loss: 0.0013
# Epoch [7/32], Step [310/338], Loss: 0.0016
# Epoch [7/32], Step [320/338], Loss: 0.0044
# Epoch [7/32], Step [330/338], Loss: 0.0010
#
# train-loss: 0.0900, train-acc: 99.6300
# validation loss: 0.3365, validation acc: 80.3379
#
# Epoch 8
#
# Epoch [8/32], Step [0/338], Loss: 0.0009
# Epoch [8/32], Step [10/338], Loss: 0.0012
# Epoch [8/32], Step [20/338], Loss: 0.1277
# Epoch [8/32], Step [30/338], Loss: 0.1705
# Epoch [8/32], Step [40/338], Loss: 0.0013
# Epoch [8/32], Step [50/338], Loss: 0.0015
# Epoch [8/32], Step [60/338], Loss: 0.0066
# Epoch [8/32], Step [70/338], Loss: 0.0014
# Epoch [8/32], Step [80/338], Loss: 0.0015
# Epoch [8/32], Step [90/338], Loss: 0.0097
# Epoch [8/32], Step [100/338], Loss: 0.0043
# Epoch [8/32], Step [110/338], Loss: 0.0024
# Epoch [8/32], Step [120/338], Loss: 0.0030
# Epoch [8/32], Step [130/338], Loss: 0.0009
# Epoch [8/32], Step [140/338], Loss: 0.0033
# Epoch [8/32], Step [150/338], Loss: 0.0015
# Epoch [8/32], Step [160/338], Loss: 0.0092
# Epoch [8/32], Step [170/338], Loss: 0.0035
# Epoch [8/32], Step [180/338], Loss: 0.0045
# Epoch [8/32], Step [190/338], Loss: 0.0022
# Epoch [8/32], Step [200/338], Loss: 0.0076
# Epoch [8/32], Step [210/338], Loss: 0.0028
# Epoch [8/32], Step [220/338], Loss: 0.0038
# Epoch [8/32], Step [230/338], Loss: 0.0063
# Epoch [8/32], Step [240/338], Loss: 0.0011
# Epoch [8/32], Step [250/338], Loss: 0.0012
# Epoch [8/32], Step [260/338], Loss: 0.0066
# Epoch [8/32], Step [270/338], Loss: 0.0006
# Epoch [8/32], Step [280/338], Loss: 0.0014
# Epoch [8/32], Step [290/338], Loss: 0.0030
# Epoch [8/32], Step [300/338], Loss: 0.0076
# Epoch [8/32], Step [310/338], Loss: 0.0188
# Epoch [8/32], Step [320/338], Loss: 0.0059
# Epoch [8/32], Step [330/338], Loss: 0.0068
#
# train-loss: 0.0802, train-acc: 100.0000
# validation loss: 0.3291, validation acc: 86.3287
#
# Epoch 9
#
# Epoch [9/32], Step [0/338], Loss: 0.0012
# Epoch [9/32], Step [10/338], Loss: 0.0026
# Epoch [9/32], Step [20/338], Loss: 0.0085
# Epoch [9/32], Step [30/338], Loss: 0.0024
# Epoch [9/32], Step [40/338], Loss: 0.0082
# Epoch [9/32], Step [50/338], Loss: 0.0041
# Epoch [9/32], Step [60/338], Loss: 0.1614
# Epoch [9/32], Step [70/338], Loss: 0.0006
# Epoch [9/32], Step [80/338], Loss: 0.0012
# Epoch [9/32], Step [90/338], Loss: 0.0019
# Epoch [9/32], Step [100/338], Loss: 0.0078
# Epoch [9/32], Step [110/338], Loss: 0.0183
# Epoch [9/32], Step [120/338], Loss: 0.0036
# Epoch [9/32], Step [130/338], Loss: 0.0017
# Epoch [9/32], Step [140/338], Loss: 0.0035
# Epoch [9/32], Step [150/338], Loss: 0.0029
# Epoch [9/32], Step [160/338], Loss: 0.0150
# Epoch [9/32], Step [170/338], Loss: 0.0052
# Epoch [9/32], Step [180/338], Loss: 0.0010
# Epoch [9/32], Step [190/338], Loss: 0.0249
# Epoch [9/32], Step [200/338], Loss: 0.0008
# Epoch [9/32], Step [210/338], Loss: 0.0020
# Epoch [9/32], Step [220/338], Loss: 0.0030
# Epoch [9/32], Step [230/338], Loss: 0.0013
# Epoch [9/32], Step [240/338], Loss: 0.0025
# Epoch [9/32], Step [250/338], Loss: 0.0031
# Epoch [9/32], Step [260/338], Loss: 0.0022
# Epoch [9/32], Step [270/338], Loss: 0.0719
# Epoch [9/32], Step [280/338], Loss: 0.0020
# Epoch [9/32], Step [290/338], Loss: 0.0025
# Epoch [9/32], Step [300/338], Loss: 0.0022
# Epoch [9/32], Step [310/338], Loss: 0.0042
# Epoch [9/32], Step [320/338], Loss: 0.0738
# Epoch [9/32], Step [330/338], Loss: 0.0005
#
# train-loss: 0.0728, train-acc: 99.8520
# validation loss: 0.3074, validation acc: 95.5453
#
# Improvement-Detected, save-model
# Epoch 10
#
# Epoch [10/32], Step [0/338], Loss: 0.0047
# Epoch [10/32], Step [10/338], Loss: 0.0020
# Epoch [10/32], Step [20/338], Loss: 0.0027
# Epoch [10/32], Step [30/338], Loss: 0.0019
# Epoch [10/32], Step [40/338], Loss: 0.0015
# Epoch [10/32], Step [50/338], Loss: 0.0021
# Epoch [10/32], Step [60/338], Loss: 0.0026
# Epoch [10/32], Step [70/338], Loss: 0.0030
# Epoch [10/32], Step [80/338], Loss: 0.0045
# Epoch [10/32], Step [90/338], Loss: 0.0009
# Epoch [10/32], Step [100/338], Loss: 0.0006
# Epoch [10/32], Step [110/338], Loss: 0.0006
# Epoch [10/32], Step [120/338], Loss: 0.2002
# Epoch [10/32], Step [130/338], Loss: 0.0020
# Epoch [10/32], Step [140/338], Loss: 0.1425
# Epoch [10/32], Step [150/338], Loss: 0.0033
# Epoch [10/32], Step [160/338], Loss: 0.0054
# Epoch [10/32], Step [170/338], Loss: 0.0006
# Epoch [10/32], Step [180/338], Loss: 0.0008
# Epoch [10/32], Step [190/338], Loss: 0.0021
# Epoch [10/32], Step [200/338], Loss: 0.0008
# Epoch [10/32], Step [210/338], Loss: 0.0056
# Epoch [10/32], Step [220/338], Loss: 0.1331
# Epoch [10/32], Step [230/338], Loss: 0.0005
# Epoch [10/32], Step [240/338], Loss: 0.0009
# Epoch [10/32], Step [250/338], Loss: 0.0019
# Epoch [10/32], Step [260/338], Loss: 0.0434
# Epoch [10/32], Step [270/338], Loss: 0.0013
# Epoch [10/32], Step [280/338], Loss: 0.0004
# Epoch [10/32], Step [290/338], Loss: 0.0014
# Epoch [10/32], Step [300/338], Loss: 0.0098
# Epoch [10/32], Step [310/338], Loss: 0.0016
# Epoch [10/32], Step [320/338], Loss: 0.0068
# Epoch [10/32], Step [330/338], Loss: 0.0054
#
# train-loss: 0.0669, train-acc: 99.8150
# validation loss: 0.3082, validation acc: 83.1029
#
# Epoch 11
#
# Epoch [11/32], Step [0/338], Loss: 0.0143
# Epoch [11/32], Step [10/338], Loss: 0.0047
# Epoch [11/32], Step [20/338], Loss: 0.0153
# Epoch [11/32], Step [30/338], Loss: 0.0020
# Epoch [11/32], Step [40/338], Loss: 0.0036
# Epoch [11/32], Step [50/338], Loss: 0.0013
# Epoch [11/32], Step [60/338], Loss: 0.0041
# Epoch [11/32], Step [70/338], Loss: 0.0125
# Epoch [11/32], Step [80/338], Loss: 0.0005
# Epoch [11/32], Step [90/338], Loss: 0.0007
# Epoch [11/32], Step [100/338], Loss: 0.0045
# Epoch [11/32], Step [110/338], Loss: 0.0171
# Epoch [11/32], Step [120/338], Loss: 0.0006
# Epoch [11/32], Step [130/338], Loss: 0.0017
# Epoch [11/32], Step [140/338], Loss: 0.0017
# Epoch [11/32], Step [150/338], Loss: 0.0031
# Epoch [11/32], Step [160/338], Loss: 0.0048
# Epoch [11/32], Step [170/338], Loss: 0.0021
# Epoch [11/32], Step [180/338], Loss: 0.0021
# Epoch [11/32], Step [190/338], Loss: 0.0029
# Epoch [11/32], Step [200/338], Loss: 0.0004
# Epoch [11/32], Step [210/338], Loss: 0.0045
# Epoch [11/32], Step [220/338], Loss: 0.0022
# Epoch [11/32], Step [230/338], Loss: 0.0012
# Epoch [11/32], Step [240/338], Loss: 0.0025
# Epoch [11/32], Step [250/338], Loss: 0.0013
# Epoch [11/32], Step [260/338], Loss: 0.0006
# Epoch [11/32], Step [270/338], Loss: 0.0007
# Epoch [11/32], Step [280/338], Loss: 0.0006
# Epoch [11/32], Step [290/338], Loss: 0.0045
# Epoch [11/32], Step [300/338], Loss: 0.0040
# Epoch [11/32], Step [310/338], Loss: 0.0414
# Epoch [11/32], Step [320/338], Loss: 0.0025
# Epoch [11/32], Step [330/338], Loss: 0.0007
#
# train-loss: 0.0617, train-acc: 99.9260
# validation loss: 0.3165, validation acc: 78.3410
#
# Epoch 12
#
# Epoch [12/32], Step [0/338], Loss: 0.0014
# Epoch [12/32], Step [10/338], Loss: 0.0147
# Epoch [12/32], Step [20/338], Loss: 0.0499
# Epoch [12/32], Step [30/338], Loss: 0.0078
# Epoch [12/32], Step [40/338], Loss: 0.0016
# Epoch [12/32], Step [50/338], Loss: 0.0020
# Epoch [12/32], Step [60/338], Loss: 0.0013
# Epoch [12/32], Step [70/338], Loss: 0.0007
# Epoch [12/32], Step [80/338], Loss: 0.0097
# Epoch [12/32], Step [90/338], Loss: 0.0022
# Epoch [12/32], Step [100/338], Loss: 1.1763
# Epoch [12/32], Step [110/338], Loss: 0.0013
# Epoch [12/32], Step [120/338], Loss: 0.0021
# Epoch [12/32], Step [130/338], Loss: 0.0013
# Epoch [12/32], Step [140/338], Loss: 0.0013
# Epoch [12/32], Step [150/338], Loss: 0.0013
# Epoch [12/32], Step [160/338], Loss: 0.3288
# Epoch [12/32], Step [170/338], Loss: 0.0013
# Epoch [12/32], Step [180/338], Loss: 0.0004
# Epoch [12/32], Step [190/338], Loss: 0.0031
# Epoch [12/32], Step [200/338], Loss: 0.0146
# Epoch [12/32], Step [210/338], Loss: 0.0046
# Epoch [12/32], Step [220/338], Loss: 0.0034
# Epoch [12/32], Step [230/338], Loss: 0.0068
# Epoch [12/32], Step [240/338], Loss: 0.0064
# Epoch [12/32], Step [250/338], Loss: 0.0218
# Epoch [12/32], Step [260/338], Loss: 0.0060
# Epoch [12/32], Step [270/338], Loss: 0.0003
# Epoch [12/32], Step [280/338], Loss: 0.0175
# Epoch [12/32], Step [290/338], Loss: 0.0007
# Epoch [12/32], Step [300/338], Loss: 0.0028
# Epoch [12/32], Step [310/338], Loss: 0.0629
# Epoch [12/32], Step [320/338], Loss: 0.0070
# Epoch [12/32], Step [330/338], Loss: 0.0032
#
# train-loss: 0.0579, train-acc: 99.6300
# validation loss: 0.3054, validation acc: 92.3195
#
# Epoch 13
#
# Epoch [13/32], Step [0/338], Loss: 0.0058
# Epoch [13/32], Step [10/338], Loss: 0.1685
# Epoch [13/32], Step [20/338], Loss: 0.0011
# Epoch [13/32], Step [30/338], Loss: 0.0053
# Epoch [13/32], Step [40/338], Loss: 0.0026
# Epoch [13/32], Step [50/338], Loss: 0.0181
# Epoch [13/32], Step [60/338], Loss: 0.0134
# Epoch [13/32], Step [70/338], Loss: 0.0331
# Epoch [13/32], Step [80/338], Loss: 0.0112
# Epoch [13/32], Step [90/338], Loss: 0.0081
# Epoch [13/32], Step [100/338], Loss: 0.1376
# Epoch [13/32], Step [110/338], Loss: 0.0013
# Epoch [13/32], Step [120/338], Loss: 0.0108
# Epoch [13/32], Step [130/338], Loss: 0.0093
# Epoch [13/32], Step [140/338], Loss: 0.0280
# Epoch [13/32], Step [150/338], Loss: 0.0004
# Epoch [13/32], Step [160/338], Loss: 0.0390
# Epoch [13/32], Step [170/338], Loss: 0.0018
# Epoch [13/32], Step [180/338], Loss: 0.0018
# Epoch [13/32], Step [190/338], Loss: 0.0015
# Epoch [13/32], Step [200/338], Loss: 0.0290
# Epoch [13/32], Step [210/338], Loss: 0.0105
# Epoch [13/32], Step [220/338], Loss: 0.0067
# Epoch [13/32], Step [230/338], Loss: 0.0012
# Epoch [13/32], Step [240/338], Loss: 0.0073
# Epoch [13/32], Step [250/338], Loss: 0.0046
# Epoch [13/32], Step [260/338], Loss: 0.0015
# Epoch [13/32], Step [270/338], Loss: 0.0003
# Epoch [13/32], Step [280/338], Loss: 0.0046
# Epoch [13/32], Step [290/338], Loss: 0.0308
# Epoch [13/32], Step [300/338], Loss: 0.0349
# Epoch [13/32], Step [310/338], Loss: 0.0067
# Epoch [13/32], Step [320/338], Loss: 0.0055
# Epoch [13/32], Step [330/338], Loss: 0.0012
#
# train-loss: 0.0545, train-acc: 99.8520
# validation loss: 0.3045, validation acc: 84.7926
#
# Epoch 14
#
# Epoch [14/32], Step [0/338], Loss: 0.0004
# Epoch [14/32], Step [10/338], Loss: 0.0012
# Epoch [14/32], Step [20/338], Loss: 0.0042
# Epoch [14/32], Step [30/338], Loss: 0.0024
# Epoch [14/32], Step [40/338], Loss: 0.0022
# Epoch [14/32], Step [50/338], Loss: 0.0005
# Epoch [14/32], Step [60/338], Loss: 0.0013
# Epoch [14/32], Step [70/338], Loss: 0.0008
# Epoch [14/32], Step [80/338], Loss: 0.0007
# Epoch [14/32], Step [90/338], Loss: 0.0018
# Epoch [14/32], Step [100/338], Loss: 0.0037
# Epoch [14/32], Step [110/338], Loss: 0.0004
# Epoch [14/32], Step [120/338], Loss: 0.0004
# Epoch [14/32], Step [130/338], Loss: 0.0003
# Epoch [14/32], Step [140/338], Loss: 0.0024
# Epoch [14/32], Step [150/338], Loss: 0.0003
# Epoch [14/32], Step [160/338], Loss: 0.0004
# Epoch [14/32], Step [170/338], Loss: 0.0016
# Epoch [14/32], Step [180/338], Loss: 0.0062
# Epoch [14/32], Step [190/338], Loss: 0.0040
# Epoch [14/32], Step [200/338], Loss: 0.0014
# Epoch [14/32], Step [210/338], Loss: 0.0004
# Epoch [14/32], Step [220/338], Loss: 0.0028
# Epoch [14/32], Step [230/338], Loss: 0.0014
# Epoch [14/32], Step [240/338], Loss: 0.0118
# Epoch [14/32], Step [250/338], Loss: 0.0013
# Epoch [14/32], Step [260/338], Loss: 0.0013
# Epoch [14/32], Step [270/338], Loss: 0.0004
# Epoch [14/32], Step [280/338], Loss: 0.0012
# Epoch [14/32], Step [290/338], Loss: 0.0004
# Epoch [14/32], Step [300/338], Loss: 0.0005
# Epoch [14/32], Step [310/338], Loss: 0.0012
# Epoch [14/32], Step [320/338], Loss: 0.0005
# Epoch [14/32], Step [330/338], Loss: 0.0084
#
# train-loss: 0.0510, train-acc: 100.0000
# validation loss: 0.3042, validation acc: 85.4071
#
# Epoch 15
#
# Epoch [15/32], Step [0/338], Loss: 0.0004
# Epoch [15/32], Step [10/338], Loss: 0.0011
# Epoch [15/32], Step [20/338], Loss: 0.0023
# Epoch [15/32], Step [30/338], Loss: 0.0011
# Epoch [15/32], Step [40/338], Loss: 0.0081
# Epoch [15/32], Step [50/338], Loss: 0.0047
# Epoch [15/32], Step [60/338], Loss: 0.0028
# Epoch [15/32], Step [70/338], Loss: 0.0084
# Epoch [15/32], Step [80/338], Loss: 0.0015
# Epoch [15/32], Step [90/338], Loss: 0.0006
# Epoch [15/32], Step [100/338], Loss: 0.0016
# Epoch [15/32], Step [110/338], Loss: 0.0042
# Epoch [15/32], Step [120/338], Loss: 0.0115
# Epoch [15/32], Step [130/338], Loss: 0.0002
# Epoch [15/32], Step [140/338], Loss: 0.0007
# Epoch [15/32], Step [150/338], Loss: 0.0028
# Epoch [15/32], Step [160/338], Loss: 0.0147
# Epoch [15/32], Step [170/338], Loss: 0.0688
# Epoch [15/32], Step [180/338], Loss: 0.0010
# Epoch [15/32], Step [190/338], Loss: 0.0010
# Epoch [15/32], Step [200/338], Loss: 0.0027
# Epoch [15/32], Step [210/338], Loss: 0.0010
# Epoch [15/32], Step [220/338], Loss: 0.0063
# Epoch [15/32], Step [230/338], Loss: 0.0035
# Epoch [15/32], Step [240/338], Loss: 0.0014
# Epoch [15/32], Step [250/338], Loss: 0.0036
# Epoch [15/32], Step [260/338], Loss: 0.0024
# Epoch [15/32], Step [270/338], Loss: 0.0057
# Epoch [15/32], Step [280/338], Loss: 0.0012
# Epoch [15/32], Step [290/338], Loss: 0.0003
# Epoch [15/32], Step [300/338], Loss: 0.0013
# Epoch [15/32], Step [310/338], Loss: 0.0040
# Epoch [15/32], Step [320/338], Loss: 0.0004
# Epoch [15/32], Step [330/338], Loss: 0.0056
#
# train-loss: 0.0481, train-acc: 99.9260
# validation loss: 0.3084, validation acc: 80.1843
#
# Epoch 16
#
# Epoch [16/32], Step [0/338], Loss: 0.0041
# Epoch [16/32], Step [10/338], Loss: 0.0009
# Epoch [16/32], Step [20/338], Loss: 0.0003
# Epoch [16/32], Step [30/338], Loss: 0.0075
# Epoch [16/32], Step [40/338], Loss: 0.0241
# Epoch [16/32], Step [50/338], Loss: 0.0011
# Epoch [16/32], Step [60/338], Loss: 0.0016
# Epoch [16/32], Step [70/338], Loss: 0.0012
# Epoch [16/32], Step [80/338], Loss: 0.1140
# Epoch [16/32], Step [90/338], Loss: 0.0009
# Epoch [16/32], Step [100/338], Loss: 0.0028
# Epoch [16/32], Step [110/338], Loss: 0.0015
# Epoch [16/32], Step [120/338], Loss: 0.0047
# Epoch [16/32], Step [130/338], Loss: 0.0002
# Epoch [16/32], Step [140/338], Loss: 0.0633
# Epoch [16/32], Step [150/338], Loss: 0.0010
# Epoch [16/32], Step [160/338], Loss: 0.0003
# Epoch [16/32], Step [170/338], Loss: 0.0074
# Epoch [16/32], Step [180/338], Loss: 0.0032
# Epoch [16/32], Step [190/338], Loss: 0.0002
# Epoch [16/32], Step [200/338], Loss: 0.7501
# Epoch [16/32], Step [210/338], Loss: 0.0013
# Epoch [16/32], Step [220/338], Loss: 0.0013
# Epoch [16/32], Step [230/338], Loss: 0.0003
# Epoch [16/32], Step [240/338], Loss: 0.0066
# Epoch [16/32], Step [250/338], Loss: 1.4329
# Epoch [16/32], Step [260/338], Loss: 0.0004
# Epoch [16/32], Step [270/338], Loss: 0.0003
# Epoch [16/32], Step [280/338], Loss: 0.0014
# Epoch [16/32], Step [290/338], Loss: 0.0058
# Epoch [16/32], Step [300/338], Loss: 0.0044
# Epoch [16/32], Step [310/338], Loss: 0.0004
# Epoch [16/32], Step [320/338], Loss: 0.0009
# Epoch [16/32], Step [330/338], Loss: 0.0050
#
# train-loss: 0.0460, train-acc: 99.7410
# validation loss: 0.2969, validation acc: 95.0845
#
# Improvement-Detected, save-model
# Epoch 17
#
# Epoch [17/32], Step [0/338], Loss: 0.0003
# Epoch [17/32], Step [10/338], Loss: 0.0009
# Epoch [17/32], Step [20/338], Loss: 0.0013
# Epoch [17/32], Step [30/338], Loss: 0.0051
# Epoch [17/32], Step [40/338], Loss: 0.0004
# Epoch [17/32], Step [50/338], Loss: 0.0009
# Epoch [17/32], Step [60/338], Loss: 0.0033
# Epoch [17/32], Step [70/338], Loss: 0.0013
# Epoch [17/32], Step [80/338], Loss: 0.0009
# Epoch [17/32], Step [90/338], Loss: 0.0061
# Epoch [17/32], Step [100/338], Loss: 0.0014
# Epoch [17/32], Step [110/338], Loss: 0.0003
# Epoch [17/32], Step [120/338], Loss: 0.0034
# Epoch [17/32], Step [130/338], Loss: 0.0093
# Epoch [17/32], Step [140/338], Loss: 0.0003
# Epoch [17/32], Step [150/338], Loss: 0.0003
# Epoch [17/32], Step [160/338], Loss: 0.0344
# Epoch [17/32], Step [170/338], Loss: 0.0008
# Epoch [17/32], Step [180/338], Loss: 0.0004
# Epoch [17/32], Step [190/338], Loss: 0.0037
# Epoch [17/32], Step [200/338], Loss: 0.0003
# Epoch [17/32], Step [210/338], Loss: 0.0004
# Epoch [17/32], Step [220/338], Loss: 0.0011
# Epoch [17/32], Step [230/338], Loss: 0.0069
# Epoch [17/32], Step [240/338], Loss: 0.0002
# Epoch [17/32], Step [250/338], Loss: 0.0300
# Epoch [17/32], Step [260/338], Loss: 0.0018
# Epoch [17/32], Step [270/338], Loss: 0.0009
# Epoch [17/32], Step [280/338], Loss: 0.0009
# Epoch [17/32], Step [290/338], Loss: 0.0016
# Epoch [17/32], Step [300/338], Loss: 0.0037
# Epoch [17/32], Step [310/338], Loss: 0.0065
# Epoch [17/32], Step [320/338], Loss: 0.0056
# Epoch [17/32], Step [330/338], Loss: 0.0003
#
# train-loss: 0.0438, train-acc: 99.9260
# validation loss: 0.2963, validation acc: 85.2535
#
# Epoch 18
#
# Epoch [18/32], Step [0/338], Loss: 0.0008
# Epoch [18/32], Step [10/338], Loss: 0.0040
# Epoch [18/32], Step [20/338], Loss: 0.0039
# Epoch [18/32], Step [30/338], Loss: 0.0068
# Epoch [18/32], Step [40/338], Loss: 0.0094
# Epoch [18/32], Step [50/338], Loss: 0.0003
# Epoch [18/32], Step [60/338], Loss: 0.0004
# Epoch [18/32], Step [70/338], Loss: 0.0116
# Epoch [18/32], Step [80/338], Loss: 0.0009
# Epoch [18/32], Step [90/338], Loss: 0.0002
# Epoch [18/32], Step [100/338], Loss: 0.0002
# Epoch [18/32], Step [110/338], Loss: 0.0022
# Epoch [18/32], Step [120/338], Loss: 0.0050
# Epoch [18/32], Step [130/338], Loss: 0.0010
# Epoch [18/32], Step [140/338], Loss: 0.0058
# Epoch [18/32], Step [150/338], Loss: 0.0010
# Epoch [18/32], Step [160/338], Loss: 0.0013
# Epoch [18/32], Step [170/338], Loss: 0.0006
# Epoch [18/32], Step [180/338], Loss: 0.0003
# Epoch [18/32], Step [190/338], Loss: 0.0028
# Epoch [18/32], Step [200/338], Loss: 0.0020
# Epoch [18/32], Step [210/338], Loss: 0.0007
# Epoch [18/32], Step [220/338], Loss: 0.0004
# Epoch [18/32], Step [230/338], Loss: 0.0016
# Epoch [18/32], Step [240/338], Loss: 0.0003
# Epoch [18/32], Step [250/338], Loss: 0.0007
# Epoch [18/32], Step [260/338], Loss: 0.0016
# Epoch [18/32], Step [270/338], Loss: 0.0019
# Epoch [18/32], Step [280/338], Loss: 0.0024
# Epoch [18/32], Step [290/338], Loss: 0.0049
# Epoch [18/32], Step [300/338], Loss: 0.0003
# Epoch [18/32], Step [310/338], Loss: 0.0011
# Epoch [18/32], Step [320/338], Loss: 0.0015
# Epoch [18/32], Step [330/338], Loss: 0.0033
#
# train-loss: 0.0416, train-acc: 100.0000
# validation loss: 0.2973, validation acc: 84.4854
#
# Epoch 19
#
# Epoch [19/32], Step [0/338], Loss: 0.0002
# Epoch [19/32], Step [10/338], Loss: 0.0008
# Epoch [19/32], Step [20/338], Loss: 0.0004
# Epoch [19/32], Step [30/338], Loss: 0.0003
# Epoch [19/32], Step [40/338], Loss: 0.0005
# Epoch [19/32], Step [50/338], Loss: 0.0048
# Epoch [19/32], Step [60/338], Loss: 0.0003
# Epoch [19/32], Step [70/338], Loss: 0.0003
# Epoch [19/32], Step [80/338], Loss: 0.0001
# Epoch [19/32], Step [90/338], Loss: 0.0002
# Epoch [19/32], Step [100/338], Loss: 0.0006
# Epoch [19/32], Step [110/338], Loss: 0.0006
# Epoch [19/32], Step [120/338], Loss: 0.0009
# Epoch [19/32], Step [130/338], Loss: 0.0003
# Epoch [19/32], Step [140/338], Loss: 0.0337
# Epoch [19/32], Step [150/338], Loss: 0.0042
# Epoch [19/32], Step [160/338], Loss: 0.0002
# Epoch [19/32], Step [170/338], Loss: 0.0009
# Epoch [19/32], Step [180/338], Loss: 0.0065
# Epoch [19/32], Step [190/338], Loss: 0.0001
# Epoch [19/32], Step [200/338], Loss: 0.0004
# Epoch [19/32], Step [210/338], Loss: 0.0048
# Epoch [19/32], Step [220/338], Loss: 0.0077
# Epoch [19/32], Step [230/338], Loss: 0.0038
# Epoch [19/32], Step [240/338], Loss: 0.0016
# Epoch [19/32], Step [250/338], Loss: 0.0192
# Epoch [19/32], Step [260/338], Loss: 0.0197
# Epoch [19/32], Step [270/338], Loss: 0.0003
# Epoch [19/32], Step [280/338], Loss: 0.0007
# Epoch [19/32], Step [290/338], Loss: 0.0002
# Epoch [19/32], Step [300/338], Loss: 0.0009
# Epoch [19/32], Step [310/338], Loss: 0.0049
# Epoch [19/32], Step [320/338], Loss: 0.0006
# Epoch [19/32], Step [330/338], Loss: 0.0020
#
# train-loss: 0.0398, train-acc: 99.9260
# validation loss: 0.2990, validation acc: 84.1782
#
# Epoch 20
#
# Epoch [20/32], Step [0/338], Loss: 0.0017
# Epoch [20/32], Step [10/338], Loss: 0.0009
# Epoch [20/32], Step [20/338], Loss: 0.0002
# Epoch [20/32], Step [30/338], Loss: 0.0003
# Epoch [20/32], Step [40/338], Loss: 0.0018
# Epoch [20/32], Step [50/338], Loss: 0.0007
# Epoch [20/32], Step [60/338], Loss: 0.0009
# Epoch [20/32], Step [70/338], Loss: 0.0011
# Epoch [20/32], Step [80/338], Loss: 0.0025
# Epoch [20/32], Step [90/338], Loss: 0.0007
# Epoch [20/32], Step [100/338], Loss: 0.0088
# Epoch [20/32], Step [110/338], Loss: 0.0009
# Epoch [20/32], Step [120/338], Loss: 0.0004
# Epoch [20/32], Step [130/338], Loss: 0.0003
# Epoch [20/32], Step [140/338], Loss: 0.0002
# Epoch [20/32], Step [150/338], Loss: 0.0016
# Epoch [20/32], Step [160/338], Loss: 0.0009
# Epoch [20/32], Step [170/338], Loss: 0.0002
# Epoch [20/32], Step [180/338], Loss: 0.0002
# Epoch [20/32], Step [190/338], Loss: 0.2080
# Epoch [20/32], Step [200/338], Loss: 0.0028
# Epoch [20/32], Step [210/338], Loss: 0.0516
# Epoch [20/32], Step [220/338], Loss: 0.0008
# Epoch [20/32], Step [230/338], Loss: 0.0006
# Epoch [20/32], Step [240/338], Loss: 0.0001
# Epoch [20/32], Step [250/338], Loss: 0.0002
# Epoch [20/32], Step [260/338], Loss: 0.0002
# Epoch [20/32], Step [270/338], Loss: 0.0004
# Epoch [20/32], Step [280/338], Loss: 0.0095
# Epoch [20/32], Step [290/338], Loss: 0.0041
# Epoch [20/32], Step [300/338], Loss: 0.0009
# Epoch [20/32], Step [310/338], Loss: 0.0007
# Epoch [20/32], Step [320/338], Loss: 0.0007
# Epoch [20/32], Step [330/338], Loss: 0.0057
#
# train-loss: 0.0381, train-acc: 100.0000
# validation loss: 0.3040, validation acc: 80.4916
#
# Epoch 21
#
# Epoch [21/32], Step [0/338], Loss: 0.0613
# Epoch [21/32], Step [10/338], Loss: 0.0006
# Epoch [21/32], Step [20/338], Loss: 0.0016
# Epoch [21/32], Step [30/338], Loss: 0.0002
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9868\832470856.py in <module>
#      14     total=0
#      15     print(f'Epoch {epoch}\n')
# ---> 16     for batch_idx, (data_, target_) in enumerate(train_loader):
#      17         data_, target_ = data_.to(device), target_.to(device)
#      18         optimizer.zero_grad()
#
# c:\users\nihal\appdata\local\programs\python\python37\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# c:\users\nihal\appdata\local\programs\python\python37\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# c:\users\nihal\appdata\local\programs\python\python37\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# c:\users\nihal\appdata\local\programs\python\python37\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# ~\AppData\Local\Temp\ipykernel_9868\2267363867.py in __getitem__(self, idx)
#      24
#      25         if self.transform:
# ---> 26             image = self.transform(image)
#      27
#      28         #image = transforms.functional.crop(image, 140, 360 , 240, 240) # take only right part of the system
#
# c:\users\nihal\appdata\local\programs\python\python37\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# c:\users\nihal\appdata\local\programs\python\python37\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, pic)
#     133             Tensor: Converted image.
#     134         """
# --> 135         return F.to_tensor(pic)
#     136
#     137     def __repr__(self) -> str:
#
# c:\users\nihal\appdata\local\programs\python\python37\lib\site-packages\torchvision\transforms\functional.py in to_tensor(pic)
#     169     img = img.permute((2, 0, 1)).contiguous()
#     170     if isinstance(img, torch.ByteTensor):
# --> 171         return img.to(dtype=default_float_dtype).div(255)
#     172     else:
#     173         return img
#
# KeyboardInterrupt:

# %%
fig = plt.figure()
fig.set_figheight(6)
fig.set_figwidth(13)

plt.subplot(1, 2, 1)
plt.plot(train_loss, 'bx-', label = 'train')
plt.plot(val_loss, 'gx-', label = 'val')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc = 'upper left')

plt.subplot(1, 2, 2)
plt.plot(train_acc, 'bx-', label = 'train')
plt.plot(val_acc, 'gx-', label = 'val')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc = 'upper left')


fig.suptitle('Wide Resnet 50-2 [Accuracy - Loss Plots]')
plt.show()

# %% [markdown]
# ### Predictions

# %% [markdown]
# #### Test

# %%
model_resnet = resnet
model_resnet.load_state_dict(torch.load(path_res))


print('Test data: ')
y_true = []
y_pred = []

for i in range(len(test_dataset)):
    input, target = test_dataset[i][0], test_dataset[i][1]
    model_resnet.eval()
    with torch.no_grad():
        input = torch.unsqueeze(input, 0)
        input = input.to(device) # send data to GPU 
        predictions = model_resnet(input)
        predicted_index = predictions[0].argmax(0)

        predicted = class_mapping[predicted_index]
        expected = class_mapping[target]

    y_true.append(expected)
    y_pred.append(predicted)

get_metrics(y_true, y_pred, class_mapping)
# Out:
# Test data:
# ┌──────────────────┬─────────┬──────────────┬──────────────┬──────────────┐
# │                  │ healthy │ misalignment │ rotor damage │ Total actual │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ healthy          │ 203     │ 0            │ 3            │ 206          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ misalignment     │ 0       │ 229          │ 0            │ 229          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ rotor damage     │ 0       │ 0            │ 216          │ 216          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ Total predicted: │ 203     │ 229          │ 219          │ 651          │
# └──────────────────┴─────────┴──────────────┴──────────────┴──────────────┘
#
# ┌──────────────┬──────────┐
# │ Class        │ F1-score │
# ├──────────────┼──────────┤
# │ Healthy      │ 0.99     │
# ├──────────────┼──────────┤
# │ Misalignment │ 1.0      │
# ├──────────────┼──────────┤
# │ Rotor damage │ 0.99     │
# └──────────────┴──────────┘
#
# Recall for healthy class: 1.0
# Recall for misalignment class: 1.0
# Recall for rotor damage class: 0.99
#
# Precision for healthy class: 0.99
# Precision for misalignment class: 1.0
# Precision for rotor damage class: 1.0

# %% [markdown]
# #### Validation

# %%
print('Valid data: ')
y_true = []
y_pred = []

for i in range(len(val_dataset)):
    input, target = val_dataset[i][0], val_dataset[i][1]
    model_resnet.eval()
    with torch.no_grad():
        input = torch.unsqueeze(input, 0)
        input = input.to(device) # send data to GPU 
        predictions = model_resnet(input)
        predicted_index = predictions[0].argmax(0)

        predicted = class_mapping[predicted_index]
        expected = class_mapping[target]

    y_true.append(expected)
    y_pred.append(predicted)

get_metrics(y_true, y_pred, class_mapping)
# Out:
# Valid data:
# ┌──────────────────┬─────────┬──────────────┬──────────────┬──────────────┐
# │                  │ healthy │ misalignment │ rotor damage │ Total actual │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ healthy          │ 178     │ 0            │ 21           │ 199          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ misalignment     │ 0       │ 220          │ 0            │ 220          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ rotor damage     │ 0       │ 0            │ 229          │ 229          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ Total predicted: │ 178     │ 220          │ 250          │ 648          │
# └──────────────────┴─────────┴──────────────┴──────────────┴──────────────┘
#
# ┌──────────────┬──────────┐
# │ Class        │ F1-score │
# ├──────────────┼──────────┤
# │ Healthy      │ 0.94     │
# ├──────────────┼──────────┤
# │ Misalignment │ 1.0      │
# ├──────────────┼──────────┤
# │ Rotor damage │ 0.96     │
# └──────────────┴──────────┘
#
# Recall for healthy class: 1.0
# Recall for misalignment class: 1.0
# Recall for rotor damage class: 0.92
#
# Precision for healthy class: 0.89
# Precision for misalignment class: 1.0
# Precision for rotor damage class: 1.0

# %% [markdown]
# #### Training

# %%
print('Training data:')
y_true = []
y_pred = []

for i in range(len(train_dataset)):
    input, target = train_dataset[i][0], train_dataset[i][1]
    model_resnet.eval()
    with torch.no_grad():
        input = torch.unsqueeze(input, 0)
        input = input.to(device) # send data to GPU
        predictions = model_resnet(input)
        predicted_index = predictions[0].argmax(0)

        predicted = class_mapping[predicted_index]
        expected = class_mapping[target]

    y_true.append(expected)
    y_pred.append(predicted)

get_metrics(y_true, y_pred, class_mapping)
# Out:
# Training data:
# ┌──────────────────┬─────────┬──────────────┬──────────────┬──────────────┐
# │                  │ healthy │ misalignment │ rotor damage │ Total actual │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ healthy          │ 557     │ 0            │ 0            │ 557          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ misalignment     │ 0       │ 981          │ 0            │ 981          │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ rotor damage     │ 0       │ 0            │ 1165         │ 1165         │
# ├──────────────────┼─────────┼──────────────┼──────────────┼──────────────┤
# │ Total predicted: │ 557     │ 981          │ 1165         │ 2703         │
# └──────────────────┴─────────┴──────────────┴──────────────┴──────────────┘
#
# ┌──────────────┬──────────┐
# │ Class        │ F1-score │
# ├──────────────┼──────────┤
# │ Healthy      │ 1.0      │
# ├──────────────┼──────────┤
# │ Misalignment │ 1.0      │
# ├──────────────┼──────────┤
# │ Rotor damage │ 1.0      │
# └──────────────┴──────────┘
#
# Recall for healthy class: 1.0
# Recall for misalignment class: 1.0
# Recall for rotor damage class: 1.0
#
# Precision for healthy class: 1.0
# Precision for misalignment class: 1.0
# Precision for rotor damage class: 1.0

# %% [markdown]
# ### Different Style of Training

# %%
# n_epochs = 20
# print_every = 10
# valid_loss_min = np.Inf
# val_loss = []
# val_acc = []
# train_loss = []
# train_acc = []
# total_step = len(train_loader)
# for epoch in range(1, n_epochs+1):
#     running_loss = 0.0
#     correct = 0
#     total=0
#     print(f'Epoch {epoch}\n')
#     for batch_idx, (data_, target_) in enumerate(train_loader):
#         data_, target_ = data_.to(device), target_.to(device)
#         optimizer.zero_grad()
        
#         outputs = resnet(data_)
#         loss = criterion(outputs, target_)
#         loss.backward()
#         optimizer.step()

#         running_loss += loss.item()
#         _,pred = torch.max(outputs, dim=1)
#         correct += torch.sum(pred==target_).item()
#         total += target_.size(0)
#         if (batch_idx) % 20 == 0:
#             print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
#                    .format(epoch, n_epochs, batch_idx, total_step, loss.item()))
#     train_acc.append(100 * correct / total)
#     train_loss.append(running_loss/total_step)
#     print(f'\ntrain-loss: {np.mean(train_loss):.4f}, train-acc: {(100 * correct/total):.4f}')
#     batch_loss = 0
#     total_t=0
#     correct_t=0
#     with torch.no_grad():
#         resnet.eval()
#         for data_t, target_t in (test_loader):
#             data_t, target_t = data_t.to(device), target_t.to(device)
#             outputs_t = resnet(data_t)
#             loss_t = criterion(outputs_t, target_t)
#             batch_loss += loss_t.item()
#             _,pred_t = torch.max(outputs_t, dim=1)
#             correct_t += torch.sum(pred_t==target_t).item()
#             total_t += target_t.size(0)
#         val_acc.append(100 * correct_t/total_t)
#         val_loss.append(batch_loss/len(test_loader))
#         network_learned = batch_loss < valid_loss_min
#         print(f'validation loss: {np.mean(val_loss):.4f}, validation acc: {(100 * correct_t/total_t):.4f}\n')

        
#         if network_learned:
#             valid_loss_min = batch_loss
#             torch.save(resnet.state_dict(), "C:/Users/Nihal/Desktop/thesis/resnet18_train2.pt")
#             print('Improvement-Detected, save-model')
#     resnet.train()

# %% [markdown]
# ### Train - Validation Accuracy

# %%
# fig = plt.figure(figsize=(20,10))
# plt.title("Train-Validation Accuracy")
# plt.plot(train_acc, label='train')
# plt.plot(val_acc, label='validation')
# plt.xlabel('num_epochs', fontsize=12)
# plt.ylabel('accuracy', fontsize=12)
# plt.legend(loc='best')

# %% [markdown]
# ### Visualize Results

# %%
# def visualize_model(net, num_images=4):
#     images_so_far = 0
#     fig = plt.figure(figsize=(15, 10))
    
#     for i, data in enumerate(test_dataloader):
#         inputs, labels = data
#         if use_cuda:
#             inputs, labels = inputs.cuda(), labels.cuda()
#         outputs = net(inputs)
#         _, preds = torch.max(outputs.data, 1)
#         preds = preds.cpu().numpy() if use_cuda else preds.numpy()
#         for j in range(inputs.size()[0]):
#             images_so_far += 1
#             ax = plt.subplot(2, num_images//2, images_so_far)
#             ax.axis('off')
#             ax.set_title('predictes: {}'.format(test_dataset.classes[preds[j]]))
#             imshow(inputs[j])
            
#             if images_so_far == num_images:
#                 return 

# plt.ion()
# visualize_model(net)
# plt.ioff()
